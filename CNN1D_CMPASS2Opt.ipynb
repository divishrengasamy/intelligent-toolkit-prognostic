# %%
# !pip install talos
# Out:
# Collecting talos
#   Downloading https://files.pythonhosted.org/packages/1c/df/fff224d37a79f58f32a19427f6672d817915e9d8e92505f371e18aa12932/talos-0.4.8.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from talos) (1.14.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from talos) (0.22.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from talos) (2.2.4)
# Collecting astetik (from talos)
#   Downloading https://files.pythonhosted.org/packages/44/5d/2bef4aca2ac9bdd1910abbc09732d5904ab4d841bee71f3835522a29367a/astetik-1.9.7.tar.gz
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from talos) (0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from talos) (4.28.1)
# Collecting chances (from talos)
#   Downloading https://files.pythonhosted.org/packages/ce/71/b0d7d471a812af47f89f016e9f94aade861b8e19a828f3e8a5ec69a88403/chances-0.1.4.tar.gz (45kB)
#     100% |████████████████████████████████| 51kB 17.4MB/s
# Collecting kerasplotlib (from talos)
#   Downloading https://files.pythonhosted.org/packages/e8/2e/b8628bfef6a817da9be863f650cf67187676b10d27d94b23f248da35d2b4/kerasplotlib-0.1.4.tar.gz
# Collecting wrangle (from talos)
#   Downloading https://files.pythonhosted.org/packages/71/9b/11fec37414435e24d2592672540a1c3e358c35fe05a98c8df2e08df91000/wrangle-0.6.2.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from talos) (2.18.4)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->talos) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->talos) (2018.9)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->talos) (1.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->talos) (2.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->talos) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->talos) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->talos) (1.11.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->talos) (1.0.9)
# Collecting geonamescache (from astetik->talos)
#   Downloading https://files.pythonhosted.org/packages/f4/66/586b63536bc578a6d28ffc1114959f51b2ca1a9582f9b987206b3ba9aa86/geonamescache-1.0.1-py3-none-any.whl (775kB)
#     100% |████████████████████████████████| 778kB 22.6MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->talos) (0.20.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.6/dist-packages (from wrangle->talos) (0.8.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->talos) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->talos) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->talos) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->talos) (2.6)
# Requirement already satisfied: patsy in /usr/local/lib/python3.6/dist-packages (from statsmodels->wrangle->talos) (0.5.1)
# Building wheels for collected packages: talos, astetik, chances, kerasplotlib, wrangle
#   Building wheel for talos (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/fc/c0/0e/4c615906c2fb59915976e570b068b90c8d973d904bc71f7773
#   Building wheel for astetik (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/e1/18/8a/dce70e6d93d855d97d435d3064122e44a375930bf7bffb8e97
#   Building wheel for chances (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/a0/5c/ff/66b7352ff7b8b2b857101c734f2b8e7dc0b6840829951c8c87
#   Building wheel for kerasplotlib (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/36/6b/4c/e1fc6d7d8811940fbea1147b1519c7baa6933e4baeff904433
#   Building wheel for wrangle (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/ce/ea/67/c7756f897f70f22279c7f2bbf5be52423d85835643042fcc34
# Successfully built talos astetik chances kerasplotlib wrangle
# Installing collected packages: wrangle, geonamescache, astetik, chances, kerasplotlib, talos
# Successfully installed astetik-1.9.7 chances-0.1.4 geonamescache-1.0.1 kerasplotlib-0.1.4 talos-0.4.8 wrangle-0.6.2

# %%
import talos as ta
import keras
import time
import keras.backend as K
from keras.layers.core import Activation
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout, Conv2D, Flatten,Conv1D,Reshape

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing

# Setting seed for reproducibility
np.random.seed(1234)  
PYTHONHASHSEED = 0

# define path to save model
model_path = 'cnnid_regression_model.h5'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %% [markdown]
# Data Ingestion

# %%
# read training data - It is the aircraft engine run-to-failure data.
train_df = pd.read_csv('train_FD003.txt', sep=" ", header=None)
test_df = pd.read_csv('test_FD003.txt', sep=" ", header=None)
truth_df = pd.read_csv('RUL_FD003.txt', sep=" ", header=None)
# pick a window size of 50 cycles
sequence_length = 50

# %%
# function to reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # for one id I put all the rows in a single matrix
    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    # Iterate over two lists in parallel.
    # For example id1 have 192 rows and sequence_length is equal to 50
    # so zip iterate over two following list of numbers (0,112),(50,192)
    # 0 50 -> from row 0 to row 50
    # 1 51 -> from row 1 to row 51
    # 2 52 -> from row 2 to row 52
    # ...
    # 111 191 -> from row 111 to 191
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # For one id I put all the labels in a single matrix.
    # For example:
    # [[1]
    # [4]
    # [1]
    # [5]
    # [9]
    # ...
    # [200]] 
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    # I have to remove the first seq_length labels
    # because for one id the first sequence of seq_length size have as target
    # the last label (the previus ones are discarded).
    # All the next id's sequences will have associated step by step one label as target.
    return data_matrix[(seq_length-1):(num_elements-1), :]

# %%
# Using the scoring function

def scoring_function(true, pred):
    d = pred - true
    length = len(d)
    s = 0
    for i in range(length):
        if (d[i] < 0):
            s += np.exp((-d[i]/10))-1
        else:
            s += np.exp((d[i]/13))-1
    return s
def rmse(true, pred):
    d_squared = (pred - true)**2
    length = len(d_squared)
    err = 0
    for i in range(length):
        err += d_squared[i]
    err = np.sqrt(err/length)
    return err
def merror(true,pred):
    d=np.abs(pred-true)
    length = len(d)
    err=np.sum(d)/length
    return err

# %%
#Preprocessing
def prep_deeplearn(train_df,test_df,truth_df,sequence_length):
    #column names
    col_names=['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']
    #remove the columns 26 and 27 because of NAN values
    train_df=train_df.loc[:,0:25]
    test_df=test_df.loc[:,0:25]
    
    train_df.columns = col_names
    test_df.columns=col_names
    train_df = train_df.sort_values(['id','cycle'])
    test_df = test_df.sort_values(['id','cycle'])
    
    #remove the columns 1 because of NAN values
    truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)
    truth_df.columns = ['cycle']
    
    #Data Preprocessing
    #Training dataset
    rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
    rul.columns = ['id', 'max']
    
    train_df = train_df.merge(rul, on=['id'], how='left')
    train_df['RUL'] = train_df['max'] - train_df['cycle']
    train_df.drop('max', axis=1, inplace=True)
    
    #check columns with repeated values: setting3, s1, s5, s10, s16,s18,s19
    
    train_df.drop(train_df.columns[[4,5,9,14,20,22,23]], axis=1, inplace=True)    
    
    test_df.drop(test_df.columns[[4,5,9,14,20,22,23]], axis=1, inplace=True)
    

    # We use the ground truth dataset to generate labels for the test data.
    # generate column max for test data
    rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
    rul.columns = ['id', 'max']
    
    truth_df.columns = ['more']
    truth_df['id'] = truth_df.index + 1
    truth_df['max'] = rul['max'] + truth_df['more']
    truth_df.drop('more', axis=1, inplace=True)
    
    # generate RUL for test data
    test_df = test_df.merge(truth_df, on=['id'], how='left')
    test_df['RUL'] = test_df['max'] - test_df['cycle']
    test_df.drop('max', axis=1, inplace=True)
    
    # MinMax normalization (from 0 to 1)
    min_max_scaler = preprocessing.MinMaxScaler()
    ###TRAIN#####
    train_df['cycle_norm'] = train_df['cycle']
    cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
    norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                                 columns=cols_normalize, 
                                 index=train_df.index)
    join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
    train_df = join_df.reindex(columns = train_df.columns)
    ####TEST#####
    test_df['cycle_norm'] = test_df['cycle']
    norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                                columns=cols_normalize, 
                                index=test_df.index)
    test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
    test_df = test_join_df.reindex(columns = test_df.columns)
    test_df = test_df.reset_index(drop=True)
    test_df.head(2)
    
    
    # pick the feature columns 
    sequence_cols = train_df.columns.difference(['id','cycle','RUL'])
    
    seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique() if train_df[train_df['id']==id]['cycle'].max()>sequence_length)
    
    seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
    
    # transform each id of the test dataset in a sequence
    seq_test_gen = (list(gen_sequence(test_df[test_df['id']==id], sequence_length, sequence_cols))
           for id in test_df['id'].unique() if test_df[test_df['id']==id]['cycle'].max()>sequence_length)
    
    seq_test_array= np.concatenate(list(seq_test_gen)).astype(np.float32)
    
    label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique() if train_df[train_df['id']==id]['cycle'].max()>sequence_length]
    
    #merge labels to form an array of all labels
    label_array = np.concatenate(label_gen).astype(np.float32)
    
    return seq_array,seq_test_array,label_array,test_df

# %% [markdown]
# CNN architecture

# %%
def minimal():
    p = {'activation':['relu', 'elu', 'tanh'],
         'optimizer': ['Nadam', 'Adam'],
         'losses': ['logcosh','mean_squared_error'],
         'kernel':[3,5,10],
         'batch_size': [16,32,128,512],
         'hidden_layers': [50,100,200],
         'dropout': [0.2,0.5]
        }
    
    def cnn1d_train(seq_array,label_array,x_val, y_val,params):
        nb_in=seq_array.shape[0]
        nb_features = seq_array.shape[2]
        nb_out = label_array.shape[1]
        model = Sequential()

        #model.add(Reshape((sequence_length, nb_features)))
        model.add(Conv1D(10,kernel_size=params['kernel'],activation=params['activation'],
                           data_format = 'channels_last',
                           input_shape = (sequence_length, nb_features)))

        model.add(Conv1D(10,kernel_size=params['kernel'], activation=params['activation']))

        model.add(Conv1D(10,kernel_size=params['kernel'], activation=params['activation']))

        model.add(Conv1D(10,kernel_size=params['kernel'], activation=params['activation']))

        model.add(Conv1D(10,kernel_size=params['kernel'], activation=params['activation']))

        model.add(Flatten())
        model.add(Dropout(rate=params['dropout']))
        model.add(Dense(units=params['hidden_layers'], activation=params['activation']))
        model.add(Dense(nb_out, activation=params['activation']))

        model.compile(loss=params['losses'], optimizer=params['optimizer'],metrics=['mae','acc'])

        start=time.time()
        history = model.fit(seq_array, label_array, epochs=100, batch_size=params['batch_size'], validation_split=0.1, verbose=2,
                         callbacks = [keras.callbacks.EarlyStopping(monitor='val_acc', min_delta=0, patience=15, verbose=0, mode='max'),
                                      keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)])
                  
        end=time.time()
        run_time=end-start

        return history,model
     def cnn2d_train(seq_array,label_array,x_val, y_val,params):
        # Expand training data to picture format with 1 representing greyscale picture
        seq_array_expanded = seq_array.reshape(nb_in, sequence_length, nb_features, 1)
        nb_in=seq_array.shape[0]
        nb_features = seq_array.shape[2]
        nb_out = label_array.shape[1]
        model = Sequential()

        #model.add(Reshape((sequence_length, nb_features)))
        model.add(Conv2D(filters=10, kernel_size=params['kernel'], strides=(1,1),
                 padding='same',
                 activation=params['activation'],
                 data_format = 'channels_last',
                 input_shape = (sequence_length, nb_features, 1)))
        model.add(Conv2D(filters=10, kernel_size=params['kernel'], strides=(1,1),
                         activation=params['activation'],
                         padding='same'))
        model.add(Conv2D(filters=10, kernel_size=params['kernel'], strides=(1,1),
                         activation=params['activation'],
                         padding='same',))
        model.add(Conv2D(filters=10, kernel_size=params['kernel'], strides=(1,1),
                         activation=params['activation'],
                         padding='same'))
        model.add(Conv2D(filters=10, kernel_size=params['kernel'], strides=(1,1),
                         activation=params['activation'],
                         padding='same'))
        model.add(Flatten())
        model.add(Dropout(rate=params['dropout']))
        model.add(Dense(units=params['hidden_layers'], activation=params['activation']))
        model.add(Dense(nb_out, activation=params['activation']))

        model.compile(loss=params['losses'], optimizer=params['optimizer'],metrics=['mae','acc'])

        start=time.time()
        history = model.fit(seq_array_expanded, label_array, epochs=100, batch_size=params['batch_size'], validation_split=0.1, verbose=2,
                         callbacks = [keras.callbacks.EarlyStopping(monitor='val_acc', min_delta=0, patience=15, verbose=0, mode='max'),
                                      keras.callbacks.ModelCheckpoint(model_path,monitor='val_loss', save_best_only=True, mode='min', verbose=0)])
                  
        end=time.time()
        run_time=end-start

        return history,model
                                                                            
    scan_object = ta.Scan(seq_array, label_array, model=cnn1d_train, params=p, grid_downsample=0.1)

    return scan_object

# %%
seq_array,seq_test_array,label_array,test_df=prep_deeplearn(train_df,test_df,truth_df,sequence_length)

# %%
scan_object=minimal()
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 2s - loss: 6375.4294 - mean_absolute_error: 61.8029 - acc: 0.0067 - val_loss: 3353.5899 - val_mean_absolute_error: 47.1712 - val_acc: 0.0064
# Epoch 2/100
#  - 1s - loss: 3299.0989 - mean_absolute_error: 46.5291 - acc: 0.0059 - val_loss: 3336.2069 - val_mean_absolute_error: 46.8358 - val_acc: 0.0046
# Epoch 3/100
#  - 1s - loss: 3049.1879 - mean_absolute_error: 44.0009 - acc: 0.0075 - val_loss: 2187.2907 - val_mean_absolute_error: 34.3823 - val_acc: 0.0100
# Epoch 4/100
#  - 1s - loss: 1996.6153 - mean_absolute_error: 34.2068 - acc: 0.0100 - val_loss: 1818.9579 - val_mean_absolute_error: 31.6100 - val_acc: 0.0082
# Epoch 5/100
#  - 1s - loss: 1663.9523 - mean_absolute_error: 31.0858 - acc: 0.0117 - val_loss: 1748.4571 - val_mean_absolute_error: 30.6691 - val_acc: 0.0119
# Epoch 6/100
#  - 1s - loss: 1633.4552 - mean_absolute_error: 30.5011 - acc: 0.0127 - val_loss: 1549.0139 - val_mean_absolute_error: 29.4801 - val_acc: 0.0137
# Epoch 7/100
#  - 1s - loss: 1557.4754 - mean_absolute_error: 29.6081 - acc: 0.0119 - val_loss: 1529.5412 - val_mean_absolute_error: 28.4969 - val_acc: 0.0137
# Epoch 8/100
#  - 1s - loss: 1512.9369 - mean_absolute_error: 28.9812 - acc: 0.0115 - val_loss: 1671.7729 - val_mean_absolute_error: 28.5057 - val_acc: 0.0256
# Epoch 9/100
#  - 1s - loss: 1438.8339 - mean_absolute_error: 28.0301 - acc: 0.0128 - val_loss: 1453.5722 - val_mean_absolute_error: 27.2395 - val_acc: 0.0164
# Epoch 10/100
#  - 1s - loss: 1369.1823 - mean_absolute_error: 27.1399 - acc: 0.0129 - val_loss: 1407.4481 - val_mean_absolute_error: 27.0177 - val_acc: 0.0155
# Epoch 11/100
#  - 1s - loss: 1306.6386 - mean_absolute_error: 26.3107 - acc: 0.0160 - val_loss: 1446.0764 - val_mean_absolute_error: 29.9459 - val_acc: 0.0082
# Epoch 12/100
#  - 1s - loss: 1268.4944 - mean_absolute_error: 25.8588 - acc: 0.0180 - val_loss: 1254.3297 - val_mean_absolute_error: 26.5083 - val_acc: 0.0128
# Epoch 13/100
#  - 1s - loss: 1206.0194 - mean_absolute_error: 24.9071 - acc: 0.0160 - val_loss: 1394.8880 - val_mean_absolute_error: 24.8898 - val_acc: 0.0183
# Epoch 14/100
#  - 1s - loss: 1188.2515 - mean_absolute_error: 24.4509 - acc: 0.0197 - val_loss: 1142.3970 - val_mean_absolute_error: 24.6493 - val_acc: 0.0100
# Epoch 15/100
#  - 1s - loss: 1101.5090 - mean_absolute_error: 23.4968 - acc: 0.0172 - val_loss: 1097.6373 - val_mean_absolute_error: 22.3468 - val_acc: 0.0274
# Epoch 16/100
#  - 1s - loss: 1101.2795 - mean_absolute_error: 23.5267 - acc: 0.0158 - val_loss: 1121.2171 - val_mean_absolute_error: 21.8571 - val_acc: 0.0347
# Epoch 17/100
#  - 1s - loss: 1042.7171 - mean_absolute_error: 22.6368 - acc: 0.0172 - val_loss: 967.4149 - val_mean_absolute_error: 21.1426 - val_acc: 0.0283
# Epoch 18/100
#  - 1s - loss: 969.2773 - mean_absolute_error: 21.6715 - acc: 0.0177 - val_loss: 964.9828 - val_mean_absolute_error: 21.3549 - val_acc: 0.0164
# Epoch 19/100
#  - 1s - loss: 993.6954 - mean_absolute_error: 22.4152 - acc: 0.0197 - val_loss: 849.6733 - val_mean_absolute_error: 20.1343 - val_acc: 0.0219
# Epoch 20/100
#  - 1s - loss: 930.3628 - mean_absolute_error: 21.1996 - acc: 0.0219 - val_loss: 844.1775 - val_mean_absolute_error: 20.2551 - val_acc: 0.0082
# Epoch 21/100
#  - 1s - loss: 932.0212 - mean_absolute_error: 21.2816 - acc: 0.0210 - val_loss: 898.9440 - val_mean_absolute_error: 22.2573 - val_acc: 0.0174
# Epoch 22/100
#  - 1s - loss: 916.0154 - mean_absolute_error: 21.1624 - acc: 0.0220 - val_loss: 785.6659 - val_mean_absolute_error: 18.7768 - val_acc: 0.0283
# Epoch 23/100
#  - 1s - loss: 881.5854 - mean_absolute_error: 20.7002 - acc: 0.0214 - val_loss: 874.0391 - val_mean_absolute_error: 21.5393 - val_acc: 0.0128
# Epoch 24/100
#  - 1s - loss: 864.9846 - mean_absolute_error: 20.4653 - acc: 0.0215 - val_loss: 795.3859 - val_mean_absolute_error: 19.4743 - val_acc: 0.0274
# Epoch 25/100
#  - 1s - loss: 858.2629 - mean_absolute_error: 20.3145 - acc: 0.0231 - val_loss: 738.2444 - val_mean_absolute_error: 18.8326 - val_acc: 0.0174
# Epoch 26/100
#  - 1s - loss: 856.4198 - mean_absolute_error: 20.4421 - acc: 0.0213 - val_loss: 776.1745 - val_mean_absolute_error: 19.0835 - val_acc: 0.0301
# Epoch 27/100
#  - 1s - loss: 829.1616 - mean_absolute_error: 19.8837 - acc: 0.0214 - val_loss: 761.4178 - val_mean_absolute_error: 18.3849 - val_acc: 0.0256
# Epoch 28/100
#  - 1s - loss: 861.1871 - mean_absolute_error: 20.6339 - acc: 0.0213 - val_loss: 729.6489 - val_mean_absolute_error: 18.3517 - val_acc: 0.0247
# Epoch 29/100
#  - 1s - loss: 818.8950 - mean_absolute_error: 19.7713 - acc: 0.0242 - val_loss: 753.5113 - val_mean_absolute_error: 18.5076 - val_acc: 0.0320
# Epoch 30/100
#  - 1s - loss: 826.3975 - mean_absolute_error: 19.9579 - acc: 0.0231 - val_loss: 718.5917 - val_mean_absolute_error: 18.0810 - val_acc: 0.0219
# Epoch 31/100
#  - 1s - loss: 823.2464 - mean_absolute_error: 20.1333 - acc: 0.0200 - val_loss: 716.3352 - val_mean_absolute_error: 18.5429 - val_acc: 0.0256
#   7%|▋         | 1/14 [00:38<08:16, 38.16s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 3s - loss: 30.4694 - mean_absolute_error: 31.1503 - acc: 0.0160 - val_loss: 22.4517 - val_mean_absolute_error: 23.1307 - val_acc: 0.0137
# Epoch 2/100
#  - 3s - loss: 21.1856 - mean_absolute_error: 21.8623 - acc: 0.0196 - val_loss: 19.1387 - val_mean_absolute_error: 19.8102 - val_acc: 0.0201
# Epoch 3/100
#  - 3s - loss: 19.1119 - mean_absolute_error: 19.7864 - acc: 0.0232 - val_loss: 17.5792 - val_mean_absolute_error: 18.2505 - val_acc: 0.0292
# Epoch 4/100
#  - 3s - loss: 18.3173 - mean_absolute_error: 18.9878 - acc: 0.0270 - val_loss: 16.0757 - val_mean_absolute_error: 16.7350 - val_acc: 0.0438
# Epoch 5/100
#  - 3s - loss: 17.7746 - mean_absolute_error: 18.4427 - acc: 0.0321 - val_loss: 17.1846 - val_mean_absolute_error: 17.8521 - val_acc: 0.0292
# Epoch 6/100
#  - 3s - loss: 17.4542 - mean_absolute_error: 18.1239 - acc: 0.0272 - val_loss: 15.1916 - val_mean_absolute_error: 15.8514 - val_acc: 0.0438
# Epoch 7/100
#  - 3s - loss: 17.1595 - mean_absolute_error: 17.8250 - acc: 0.0349 - val_loss: 14.6300 - val_mean_absolute_error: 15.2864 - val_acc: 0.0438
# Epoch 8/100
#  - 3s - loss: 16.8688 - mean_absolute_error: 17.5342 - acc: 0.0337 - val_loss: 16.2267 - val_mean_absolute_error: 16.8965 - val_acc: 0.0256
# Epoch 9/100
#  - 3s - loss: 16.6940 - mean_absolute_error: 17.3594 - acc: 0.0327 - val_loss: 16.5274 - val_mean_absolute_error: 17.1971 - val_acc: 0.0311
# Epoch 10/100
#  - 3s - loss: 16.6517 - mean_absolute_error: 17.3176 - acc: 0.0339 - val_loss: 15.8153 - val_mean_absolute_error: 16.4733 - val_acc: 0.0402
# Epoch 11/100
#  - 3s - loss: 16.3260 - mean_absolute_error: 16.9887 - acc: 0.0367 - val_loss: 14.6130 - val_mean_absolute_error: 15.2741 - val_acc: 0.0420
# Epoch 12/100
#  - 3s - loss: 16.3638 - mean_absolute_error: 17.0280 - acc: 0.0349 - val_loss: 13.9790 - val_mean_absolute_error: 14.6260 - val_acc: 0.0639
# Epoch 13/100
#  - 3s - loss: 16.1011 - mean_absolute_error: 16.7642 - acc: 0.0362 - val_loss: 15.2825 - val_mean_absolute_error: 15.9497 - val_acc: 0.0356
# Epoch 14/100
#  - 3s - loss: 16.0573 - mean_absolute_error: 16.7197 - acc: 0.0371 - val_loss: 15.1203 - val_mean_absolute_error: 15.7705 - val_acc: 0.0621
# Epoch 15/100
#  - 3s - loss: 15.9162 - mean_absolute_error: 16.5797 - acc: 0.0348 - val_loss: 14.8162 - val_mean_absolute_error: 15.4848 - val_acc: 0.0329
# Epoch 16/100
#  - 3s - loss: 15.9490 - mean_absolute_error: 16.6110 - acc: 0.0379 - val_loss: 14.1876 - val_mean_absolute_error: 14.8395 - val_acc: 0.0539
# Epoch 17/100
#  - 3s - loss: 15.9736 - mean_absolute_error: 16.6371 - acc: 0.0352 - val_loss: 14.5637 - val_mean_absolute_error: 15.2239 - val_acc: 0.0393
# Epoch 18/100
#  - 3s - loss: 15.7367 - mean_absolute_error: 16.3977 - acc: 0.0378 - val_loss: 13.8718 - val_mean_absolute_error: 14.5205 - val_acc: 0.0603
# Epoch 19/100
#  - 3s - loss: 15.6967 - mean_absolute_error: 16.3572 - acc: 0.0406 - val_loss: 13.4027 - val_mean_absolute_error: 14.0384 - val_acc: 0.0731
# Epoch 20/100
#  - 3s - loss: 15.6848 - mean_absolute_error: 16.3456 - acc: 0.0409 - val_loss: 14.9382 - val_mean_absolute_error: 15.5892 - val_acc: 0.0530
# Epoch 21/100
#  - 3s - loss: 15.5362 - mean_absolute_error: 16.1961 - acc: 0.0413 - val_loss: 13.6872 - val_mean_absolute_error: 14.3388 - val_acc: 0.0511
# Epoch 22/100
#  - 3s - loss: 15.5760 - mean_absolute_error: 16.2362 - acc: 0.0418 - val_loss: 13.9491 - val_mean_absolute_error: 14.6026 - val_acc: 0.0484
# Epoch 23/100
#  - 3s - loss: 15.4040 - mean_absolute_error: 16.0660 - acc: 0.0383 - val_loss: 16.7511 - val_mean_absolute_error: 17.4328 - val_acc: 0.0119
# Epoch 24/100
#  - 3s - loss: 15.4679 - mean_absolute_error: 16.1280 - acc: 0.0385 - val_loss: 14.4172 - val_mean_absolute_error: 15.0726 - val_acc: 0.0420
# Epoch 25/100
#  - 3s - loss: 15.2228 - mean_absolute_error: 15.8816 - acc: 0.0429 - val_loss: 13.4547 - val_mean_absolute_error: 14.1108 - val_acc: 0.0420
# Epoch 26/100
#  - 3s - loss: 15.1659 - mean_absolute_error: 15.8260 - acc: 0.0409 - val_loss: 13.8485 - val_mean_absolute_error: 14.4949 - val_acc: 0.0612
# Epoch 27/100
#  - 3s - loss: 15.2742 - mean_absolute_error: 15.9321 - acc: 0.0438 - val_loss: 13.2397 - val_mean_absolute_error: 13.8874 - val_acc: 0.0603
# Epoch 28/100
#  - 3s - loss: 15.1855 - mean_absolute_error: 15.8452 - acc: 0.0398 - val_loss: 13.8472 - val_mean_absolute_error: 14.4996 - val_acc: 0.0502
# Epoch 29/100
#  - 3s - loss: 15.1631 - mean_absolute_error: 15.8230 - acc: 0.0384 - val_loss: 14.5051 - val_mean_absolute_error: 15.1575 - val_acc: 0.0530
# Epoch 30/100
#  - 3s - loss: 15.1781 - mean_absolute_error: 15.8368 - acc: 0.0439 - val_loss: 13.1629 - val_mean_absolute_error: 13.8245 - val_acc: 0.0338
# Epoch 31/100
#  - 3s - loss: 14.9060 - mean_absolute_error: 15.5656 - acc: 0.0400 - val_loss: 13.1686 - val_mean_absolute_error: 13.8238 - val_acc: 0.0447
# Epoch 32/100
#  - 3s - loss: 14.9538 - mean_absolute_error: 15.6106 - acc: 0.0464 - val_loss: 13.6888 - val_mean_absolute_error: 14.3435 - val_acc: 0.0447
# Epoch 33/100
#  - 3s - loss: 14.7849 - mean_absolute_error: 15.4440 - acc: 0.0416 - val_loss: 13.2361 - val_mean_absolute_error: 13.8891 - val_acc: 0.0502
# Epoch 34/100
#  - 3s - loss: 14.9592 - mean_absolute_error: 15.6181 - acc: 0.0417 - val_loss: 13.0128 - val_mean_absolute_error: 13.6611 - val_acc: 0.0594
#  14%|█▍        | 2/14 [02:15<11:11, 56.00s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 2s - loss: 10186.9903 - mean_absolute_error: 83.0467 - acc: 0.0036 - val_loss: 7354.2954 - val_mean_absolute_error: 65.9643 - val_acc: 0.0027
# Epoch 2/100
#  - 1s - loss: 4660.3405 - mean_absolute_error: 54.0635 - acc: 0.0067 - val_loss: 3937.9362 - val_mean_absolute_error: 48.5579 - val_acc: 0.0046
# Epoch 3/100
#  - 1s - loss: 3582.7153 - mean_absolute_error: 48.0184 - acc: 0.0051 - val_loss: 3309.0533 - val_mean_absolute_error: 45.4300 - val_acc: 0.0037
# Epoch 4/100
#  - 1s - loss: 3061.5726 - mean_absolute_error: 44.3178 - acc: 0.0072 - val_loss: 2783.6003 - val_mean_absolute_error: 42.1555 - val_acc: 0.0064
# Epoch 5/100
#  - 1s - loss: 2497.9246 - mean_absolute_error: 39.8898 - acc: 0.0067 - val_loss: 2128.9072 - val_mean_absolute_error: 35.9329 - val_acc: 0.0110
# Epoch 6/100
#  - 1s - loss: 1888.5001 - mean_absolute_error: 33.5138 - acc: 0.0082 - val_loss: 1774.9076 - val_mean_absolute_error: 30.8885 - val_acc: 0.0110
# Epoch 7/100
#  - 1s - loss: 1716.4612 - mean_absolute_error: 31.0041 - acc: 0.0101 - val_loss: 1734.2397 - val_mean_absolute_error: 29.9824 - val_acc: 0.0110
# Epoch 8/100
#  - 1s - loss: 1630.6438 - mean_absolute_error: 29.9972 - acc: 0.0136 - val_loss: 1594.8884 - val_mean_absolute_error: 29.8925 - val_acc: 0.0100
# Epoch 9/100
#  - 1s - loss: 1563.1040 - mean_absolute_error: 29.2974 - acc: 0.0163 - val_loss: 1573.0267 - val_mean_absolute_error: 28.7717 - val_acc: 0.0137
# Epoch 10/100
#  - 1s - loss: 1507.5126 - mean_absolute_error: 28.6211 - acc: 0.0138 - val_loss: 1604.4168 - val_mean_absolute_error: 28.2906 - val_acc: 0.0210
# Epoch 11/100
#  - 1s - loss: 1483.5805 - mean_absolute_error: 28.3862 - acc: 0.0178 - val_loss: 1538.0412 - val_mean_absolute_error: 27.9063 - val_acc: 0.0155
# Epoch 12/100
#  - 1s - loss: 1447.3855 - mean_absolute_error: 27.9134 - acc: 0.0165 - val_loss: 1562.5376 - val_mean_absolute_error: 27.6619 - val_acc: 0.0192
# Epoch 13/100
#  - 1s - loss: 1438.8479 - mean_absolute_error: 27.8150 - acc: 0.0149 - val_loss: 1553.0255 - val_mean_absolute_error: 27.4491 - val_acc: 0.0183
# Epoch 14/100
#  - 1s - loss: 1400.6821 - mean_absolute_error: 27.2608 - acc: 0.0145 - val_loss: 1541.1043 - val_mean_absolute_error: 27.2155 - val_acc: 0.0183
# Epoch 15/100
#  - 1s - loss: 1402.2223 - mean_absolute_error: 27.3072 - acc: 0.0154 - val_loss: 1520.4576 - val_mean_absolute_error: 26.8857 - val_acc: 0.0228
# Epoch 16/100
#  - 1s - loss: 1389.1233 - mean_absolute_error: 27.0806 - acc: 0.0155 - val_loss: 1395.1038 - val_mean_absolute_error: 26.8108 - val_acc: 0.0228
# Epoch 17/100
#  - 1s - loss: 1328.5498 - mean_absolute_error: 26.5796 - acc: 0.0160 - val_loss: 1547.5657 - val_mean_absolute_error: 26.5781 - val_acc: 0.0100
# Epoch 18/100
#  - 1s - loss: 1291.5216 - mean_absolute_error: 25.8890 - acc: 0.0164 - val_loss: 1327.7617 - val_mean_absolute_error: 25.4526 - val_acc: 0.0210
# Epoch 19/100
#  - 1s - loss: 1255.7511 - mean_absolute_error: 25.3441 - acc: 0.0211 - val_loss: 1625.5197 - val_mean_absolute_error: 26.1361 - val_acc: 0.0256
# Epoch 20/100
#  - 1s - loss: 1279.1669 - mean_absolute_error: 25.6292 - acc: 0.0178 - val_loss: 1669.3005 - val_mean_absolute_error: 27.1204 - val_acc: 0.0174
# Epoch 21/100
#  - 1s - loss: 1218.3165 - mean_absolute_error: 24.8472 - acc: 0.0202 - val_loss: 2016.4611 - val_mean_absolute_error: 29.2879 - val_acc: 0.0256
# Epoch 22/100
#  - 1s - loss: 1237.1776 - mean_absolute_error: 24.6847 - acc: 0.0195 - val_loss: 1452.1782 - val_mean_absolute_error: 24.9392 - val_acc: 0.0256
# Epoch 23/100
#  - 1s - loss: 1140.3729 - mean_absolute_error: 23.6883 - acc: 0.0199 - val_loss: 1283.3770 - val_mean_absolute_error: 23.6313 - val_acc: 0.0274
# Epoch 24/100
#  - 1s - loss: 1114.2106 - mean_absolute_error: 23.2390 - acc: 0.0245 - val_loss: 1273.7595 - val_mean_absolute_error: 23.3021 - val_acc: 0.0256
# Epoch 25/100
#  - 1s - loss: 1100.7800 - mean_absolute_error: 23.1595 - acc: 0.0231 - val_loss: 1590.2865 - val_mean_absolute_error: 25.2759 - val_acc: 0.0320
# Epoch 26/100
#  - 1s - loss: 1071.1980 - mean_absolute_error: 22.6204 - acc: 0.0251 - val_loss: 1255.0149 - val_mean_absolute_error: 22.4945 - val_acc: 0.0365
# Epoch 27/100
#  - 1s - loss: 1055.2522 - mean_absolute_error: 22.4665 - acc: 0.0269 - val_loss: 1678.4285 - val_mean_absolute_error: 26.5056 - val_acc: 0.0174
# Epoch 28/100
#  - 1s - loss: 1034.2249 - mean_absolute_error: 22.1587 - acc: 0.0271 - val_loss: 1285.0138 - val_mean_absolute_error: 22.6692 - val_acc: 0.0301
# Epoch 29/100
#  - 1s - loss: 1028.6895 - mean_absolute_error: 22.0173 - acc: 0.0285 - val_loss: 1629.7680 - val_mean_absolute_error: 25.7296 - val_acc: 0.0192
# Epoch 30/100
#  - 1s - loss: 1051.1208 - mean_absolute_error: 22.1472 - acc: 0.0243 - val_loss: 1605.9716 - val_mean_absolute_error: 25.4469 - val_acc: 0.0228
# Epoch 31/100
#  - 1s - loss: 1001.4295 - mean_absolute_error: 21.5646 - acc: 0.0267 - val_loss: 1696.4341 - val_mean_absolute_error: 26.1277 - val_acc: 0.0219
# Epoch 32/100
#  - 1s - loss: 1132.3122 - mean_absolute_error: 22.9935 - acc: 0.0234 - val_loss: 1422.8231 - val_mean_absolute_error: 23.6302 - val_acc: 0.0301
# Epoch 33/100
#  - 1s - loss: 1024.0350 - mean_absolute_error: 21.8317 - acc: 0.0249 - val_loss: 1187.6976 - val_mean_absolute_error: 21.6353 - val_acc: 0.0320
# Epoch 34/100
#  - 1s - loss: 987.3165 - mean_absolute_error: 21.3674 - acc: 0.0261 - val_loss: 1161.4717 - val_mean_absolute_error: 21.4436 - val_acc: 0.0301
# Epoch 35/100
#  - 1s - loss: 949.5371 - mean_absolute_error: 20.9955 - acc: 0.0264 - val_loss: 1379.5719 - val_mean_absolute_error: 23.0009 - val_acc: 0.0183
# Epoch 36/100
#  - 1s - loss: 972.3191 - mean_absolute_error: 21.2148 - acc: 0.0250 - val_loss: 1064.8316 - val_mean_absolute_error: 20.5959 - val_acc: 0.0256
# Epoch 37/100
#  - 1s - loss: 1061.1655 - mean_absolute_error: 22.2473 - acc: 0.0270 - val_loss: 1330.6924 - val_mean_absolute_error: 22.8682 - val_acc: 0.0274
# Epoch 38/100
#  - 1s - loss: 952.5859 - mean_absolute_error: 21.1165 - acc: 0.0237 - val_loss: 1308.7041 - val_mean_absolute_error: 22.6800 - val_acc: 0.0274
# Epoch 39/100
#  - 1s - loss: 963.5724 - mean_absolute_error: 21.0424 - acc: 0.0257 - val_loss: 1196.4697 - val_mean_absolute_error: 21.5499 - val_acc: 0.0301
# Epoch 40/100
#  - 1s - loss: 941.7583 - mean_absolute_error: 20.8748 - acc: 0.0260 - val_loss: 1235.4149 - val_mean_absolute_error: 21.8657 - val_acc: 0.0265
# Epoch 41/100
#  - 1s - loss: 934.0860 - mean_absolute_error: 20.6934 - acc: 0.0252 - val_loss: 1648.4701 - val_mean_absolute_error: 26.3055 - val_acc: 0.0228
#  21%|██▏       | 3/14 [03:11<10:15, 56.00s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 2s - loss: 55.0503 - mean_absolute_error: 55.7386 - acc: 0.0059 - val_loss: 34.9930 - val_mean_absolute_error: 35.6808 - val_acc: 0.0064
# Epoch 2/100
#  - 2s - loss: 30.7551 - mean_absolute_error: 31.4382 - acc: 0.0122 - val_loss: 29.0304 - val_mean_absolute_error: 29.7122 - val_acc: 0.0119
# Epoch 3/100
#  - 1s - loss: 27.2442 - mean_absolute_error: 27.9266 - acc: 0.0123 - val_loss: 26.8110 - val_mean_absolute_error: 27.4921 - val_acc: 0.0174
# Epoch 4/100
#  - 1s - loss: 25.1559 - mean_absolute_error: 25.8355 - acc: 0.0171 - val_loss: 22.7777 - val_mean_absolute_error: 23.4502 - val_acc: 0.0301
# Epoch 5/100
#  - 1s - loss: 21.9286 - mean_absolute_error: 22.6060 - acc: 0.0191 - val_loss: 19.7534 - val_mean_absolute_error: 20.4265 - val_acc: 0.0265
# Epoch 6/100
#  - 1s - loss: 20.7394 - mean_absolute_error: 21.4160 - acc: 0.0205 - val_loss: 19.9374 - val_mean_absolute_error: 20.6147 - val_acc: 0.0164
# Epoch 7/100
#  - 1s - loss: 20.4354 - mean_absolute_error: 21.1118 - acc: 0.0203 - val_loss: 18.2536 - val_mean_absolute_error: 18.9229 - val_acc: 0.0311
# Epoch 8/100
#  - 1s - loss: 19.8794 - mean_absolute_error: 20.5539 - acc: 0.0219 - val_loss: 18.2067 - val_mean_absolute_error: 18.8752 - val_acc: 0.0338
# Epoch 9/100
#  - 1s - loss: 19.6970 - mean_absolute_error: 20.3723 - acc: 0.0207 - val_loss: 17.4733 - val_mean_absolute_error: 18.1426 - val_acc: 0.0274
# Epoch 10/100
#  - 1s - loss: 19.2881 - mean_absolute_error: 19.9617 - acc: 0.0224 - val_loss: 17.7220 - val_mean_absolute_error: 18.3934 - val_acc: 0.0210
# Epoch 11/100
#  - 1s - loss: 19.1543 - mean_absolute_error: 19.8274 - acc: 0.0248 - val_loss: 17.2316 - val_mean_absolute_error: 17.8935 - val_acc: 0.0374
# Epoch 12/100
#  - 1s - loss: 18.7787 - mean_absolute_error: 19.4501 - acc: 0.0251 - val_loss: 17.0474 - val_mean_absolute_error: 17.7128 - val_acc: 0.0292
# Epoch 13/100
#  - 1s - loss: 18.6655 - mean_absolute_error: 19.3389 - acc: 0.0223 - val_loss: 16.7908 - val_mean_absolute_error: 17.4558 - val_acc: 0.0356
# Epoch 14/100
#  - 1s - loss: 18.4922 - mean_absolute_error: 19.1644 - acc: 0.0264 - val_loss: 16.7592 - val_mean_absolute_error: 17.4273 - val_acc: 0.0265
# Epoch 15/100
#  - 1s - loss: 18.3487 - mean_absolute_error: 19.0203 - acc: 0.0258 - val_loss: 16.7516 - val_mean_absolute_error: 17.4158 - val_acc: 0.0356
# Epoch 16/100
#  - 1s - loss: 18.3214 - mean_absolute_error: 18.9934 - acc: 0.0257 - val_loss: 16.6036 - val_mean_absolute_error: 17.2674 - val_acc: 0.0347
# Epoch 17/100
#  - 1s - loss: 18.0142 - mean_absolute_error: 18.6831 - acc: 0.0295 - val_loss: 17.0727 - val_mean_absolute_error: 17.7367 - val_acc: 0.0347
# Epoch 18/100
#  - 1s - loss: 18.0717 - mean_absolute_error: 18.7432 - acc: 0.0256 - val_loss: 16.7532 - val_mean_absolute_error: 17.4232 - val_acc: 0.0274
# Epoch 19/100
#  - 1s - loss: 17.9847 - mean_absolute_error: 18.6547 - acc: 0.0282 - val_loss: 16.5117 - val_mean_absolute_error: 17.1695 - val_acc: 0.0447
# Epoch 20/100
#  - 1s - loss: 17.9655 - mean_absolute_error: 18.6349 - acc: 0.0299 - val_loss: 18.2932 - val_mean_absolute_error: 18.9694 - val_acc: 0.0174
# Epoch 21/100
#  - 1s - loss: 18.0879 - mean_absolute_error: 18.7578 - acc: 0.0281 - val_loss: 16.3806 - val_mean_absolute_error: 17.0485 - val_acc: 0.0292
# Epoch 22/100
#  - 1s - loss: 17.6552 - mean_absolute_error: 18.3256 - acc: 0.0276 - val_loss: 15.7766 - val_mean_absolute_error: 16.4409 - val_acc: 0.0356
# Epoch 23/100
#  - 1s - loss: 17.6492 - mean_absolute_error: 18.3194 - acc: 0.0275 - val_loss: 15.9016 - val_mean_absolute_error: 16.5623 - val_acc: 0.0393
# Epoch 24/100
#  - 1s - loss: 17.5553 - mean_absolute_error: 18.2231 - acc: 0.0301 - val_loss: 15.8934 - val_mean_absolute_error: 16.5628 - val_acc: 0.0201
# Epoch 25/100
#  - 1s - loss: 17.6240 - mean_absolute_error: 18.2936 - acc: 0.0278 - val_loss: 16.7598 - val_mean_absolute_error: 17.4329 - val_acc: 0.0201
# Epoch 26/100
#  - 1s - loss: 17.3579 - mean_absolute_error: 18.0279 - acc: 0.0267 - val_loss: 15.8011 - val_mean_absolute_error: 16.4720 - val_acc: 0.0256
# Epoch 27/100
#  - 1s - loss: 17.4976 - mean_absolute_error: 18.1688 - acc: 0.0259 - val_loss: 15.6344 - val_mean_absolute_error: 16.2974 - val_acc: 0.0365
# Epoch 28/100
#  - 1s - loss: 17.4081 - mean_absolute_error: 18.0761 - acc: 0.0306 - val_loss: 15.8508 - val_mean_absolute_error: 16.5204 - val_acc: 0.0320
# Epoch 29/100
#  - 1s - loss: 17.2744 - mean_absolute_error: 17.9422 - acc: 0.0310 - val_loss: 15.4806 - val_mean_absolute_error: 16.1316 - val_acc: 0.0594
# Epoch 30/100
#  - 1s - loss: 17.0999 - mean_absolute_error: 17.7657 - acc: 0.0336 - val_loss: 15.3758 - val_mean_absolute_error: 16.0317 - val_acc: 0.0530
# Epoch 31/100
#  - 1s - loss: 16.9422 - mean_absolute_error: 17.6080 - acc: 0.0350 - val_loss: 16.3872 - val_mean_absolute_error: 17.0536 - val_acc: 0.0347
# Epoch 32/100
#  - 1s - loss: 17.1754 - mean_absolute_error: 17.8434 - acc: 0.0305 - val_loss: 15.5513 - val_mean_absolute_error: 16.2199 - val_acc: 0.0292
# Epoch 33/100
#  - 1s - loss: 16.8797 - mean_absolute_error: 17.5452 - acc: 0.0345 - val_loss: 15.3794 - val_mean_absolute_error: 16.0403 - val_acc: 0.0429
# Epoch 34/100
#  - 1s - loss: 16.8251 - mean_absolute_error: 17.4903 - acc: 0.0350 - val_loss: 14.7105 - val_mean_absolute_error: 15.3654 - val_acc: 0.0484
# Epoch 35/100
#  - 1s - loss: 16.8123 - mean_absolute_error: 17.4778 - acc: 0.0333 - val_loss: 15.2706 - val_mean_absolute_error: 15.9364 - val_acc: 0.0292
# Epoch 36/100
#  - 1s - loss: 16.9987 - mean_absolute_error: 17.6646 - acc: 0.0335 - val_loss: 15.1065 - val_mean_absolute_error: 15.7634 - val_acc: 0.0447
# Epoch 37/100
#  - 1s - loss: 16.5827 - mean_absolute_error: 17.2478 - acc: 0.0336 - val_loss: 15.0721 - val_mean_absolute_error: 15.7377 - val_acc: 0.0301
# Epoch 38/100
#  - 1s - loss: 16.3719 - mean_absolute_error: 17.0365 - acc: 0.0353 - val_loss: 14.8294 - val_mean_absolute_error: 15.4914 - val_acc: 0.0384
# Epoch 39/100
#  - 1s - loss: 16.7397 - mean_absolute_error: 17.4053 - acc: 0.0333 - val_loss: 14.6337 - val_mean_absolute_error: 15.2874 - val_acc: 0.0530
# Epoch 40/100
#  - 1s - loss: 16.5523 - mean_absolute_error: 17.2156 - acc: 0.0385 - val_loss: 15.1190 - val_mean_absolute_error: 15.7706 - val_acc: 0.0539
# Epoch 41/100
#  - 1s - loss: 16.5946 - mean_absolute_error: 17.2606 - acc: 0.0338 - val_loss: 14.8732 - val_mean_absolute_error: 15.5298 - val_acc: 0.0493
# Epoch 42/100
#  - 1s - loss: 16.5920 - mean_absolute_error: 17.2575 - acc: 0.0335 - val_loss: 15.5673 - val_mean_absolute_error: 16.2338 - val_acc: 0.0320
# Epoch 43/100
#  - 1s - loss: 16.6431 - mean_absolute_error: 17.3100 - acc: 0.0313 - val_loss: 14.5574 - val_mean_absolute_error: 15.2245 - val_acc: 0.0256
# Epoch 44/100
#  - 1s - loss: 16.2740 - mean_absolute_error: 16.9386 - acc: 0.0340 - val_loss: 14.4898 - val_mean_absolute_error: 15.1441 - val_acc: 0.0457
#  29%|██▊       | 4/14 [04:19<09:55, 59.54s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 4s - loss: 2550.8366 - mean_absolute_error: 37.5879 - acc: 0.0100 - val_loss: 1459.6878 - val_mean_absolute_error: 27.6258 - val_acc: 0.0183
# Epoch 2/100
#  - 3s - loss: 1267.0654 - mean_absolute_error: 25.9337 - acc: 0.0145 - val_loss: 1031.2172 - val_mean_absolute_error: 22.8312 - val_acc: 0.0219
# Epoch 3/100
#  - 3s - loss: 1078.2683 - mean_absolute_error: 23.3824 - acc: 0.0166 - val_loss: 991.5731 - val_mean_absolute_error: 20.1078 - val_acc: 0.0192
# Epoch 4/100
#  - 3s - loss: 993.6076 - mean_absolute_error: 22.1335 - acc: 0.0165 - val_loss: 811.6858 - val_mean_absolute_error: 18.8421 - val_acc: 0.0365
# Epoch 5/100
#  - 3s - loss: 923.4182 - mean_absolute_error: 21.2710 - acc: 0.0190 - val_loss: 827.4164 - val_mean_absolute_error: 20.0649 - val_acc: 0.0237
# Epoch 6/100
#  - 3s - loss: 916.7382 - mean_absolute_error: 21.1946 - acc: 0.0192 - val_loss: 868.2907 - val_mean_absolute_error: 18.8266 - val_acc: 0.0311
# Epoch 7/100
#  - 3s - loss: 865.7365 - mean_absolute_error: 20.4617 - acc: 0.0228 - val_loss: 711.4017 - val_mean_absolute_error: 18.3687 - val_acc: 0.0320
# Epoch 8/100
#  - 3s - loss: 883.6770 - mean_absolute_error: 20.5741 - acc: 0.0206 - val_loss: 747.2135 - val_mean_absolute_error: 20.0455 - val_acc: 0.0110
# Epoch 9/100
#  - 3s - loss: 864.0677 - mean_absolute_error: 20.3355 - acc: 0.0214 - val_loss: 747.3117 - val_mean_absolute_error: 17.6511 - val_acc: 0.0320
# Epoch 10/100
#  - 3s - loss: 835.1948 - mean_absolute_error: 19.8386 - acc: 0.0240 - val_loss: 665.6679 - val_mean_absolute_error: 17.3277 - val_acc: 0.0338
# Epoch 11/100
#  - 3s - loss: 802.1179 - mean_absolute_error: 19.3710 - acc: 0.0269 - val_loss: 716.7158 - val_mean_absolute_error: 18.6733 - val_acc: 0.0384
# Epoch 12/100
#  - 3s - loss: 799.6450 - mean_absolute_error: 19.3248 - acc: 0.0251 - val_loss: 698.6710 - val_mean_absolute_error: 18.1360 - val_acc: 0.0320
# Epoch 13/100
#  - 3s - loss: 796.3994 - mean_absolute_error: 19.1695 - acc: 0.0246 - val_loss: 702.7862 - val_mean_absolute_error: 18.6692 - val_acc: 0.0301
# Epoch 14/100
#  - 3s - loss: 772.8279 - mean_absolute_error: 18.7351 - acc: 0.0276 - val_loss: 810.4394 - val_mean_absolute_error: 19.1916 - val_acc: 0.0183
# Epoch 15/100
#  - 3s - loss: 812.7069 - mean_absolute_error: 19.4318 - acc: 0.0237 - val_loss: 744.0427 - val_mean_absolute_error: 18.0972 - val_acc: 0.0347
# Epoch 16/100
#  - 3s - loss: 784.1048 - mean_absolute_error: 18.9433 - acc: 0.0286 - val_loss: 651.2571 - val_mean_absolute_error: 15.9371 - val_acc: 0.0420
# Epoch 17/100
#  - 3s - loss: 760.3682 - mean_absolute_error: 18.7009 - acc: 0.0249 - val_loss: 597.1901 - val_mean_absolute_error: 16.6243 - val_acc: 0.0438
# Epoch 18/100
#  - 3s - loss: 738.2775 - mean_absolute_error: 18.4786 - acc: 0.0250 - val_loss: 595.5270 - val_mean_absolute_error: 16.7868 - val_acc: 0.0283
# Epoch 19/100
#  - 3s - loss: 719.7730 - mean_absolute_error: 18.1748 - acc: 0.0266 - val_loss: 597.6944 - val_mean_absolute_error: 17.2738 - val_acc: 0.0164
# Epoch 20/100
#  - 3s - loss: 701.5457 - mean_absolute_error: 18.0416 - acc: 0.0266 - val_loss: 548.4759 - val_mean_absolute_error: 15.6119 - val_acc: 0.0228
# Epoch 21/100
#  - 3s - loss: 713.7462 - mean_absolute_error: 18.0330 - acc: 0.0304 - val_loss: 681.9514 - val_mean_absolute_error: 17.7064 - val_acc: 0.0174
# Epoch 22/100
#  - 3s - loss: 699.8174 - mean_absolute_error: 17.9245 - acc: 0.0302 - val_loss: 581.1545 - val_mean_absolute_error: 16.6026 - val_acc: 0.0283
# Epoch 23/100
#  - 3s - loss: 679.0542 - mean_absolute_error: 17.6854 - acc: 0.0316 - val_loss: 541.5249 - val_mean_absolute_error: 15.4946 - val_acc: 0.0311
# Epoch 24/100
#  - 3s - loss: 654.6863 - mean_absolute_error: 17.3225 - acc: 0.0303 - val_loss: 569.3763 - val_mean_absolute_error: 16.3649 - val_acc: 0.0320
# Epoch 25/100
#  - 3s - loss: 664.8460 - mean_absolute_error: 17.4251 - acc: 0.0303 - val_loss: 505.3440 - val_mean_absolute_error: 14.8941 - val_acc: 0.0384
# Epoch 26/100
#  - 3s - loss: 647.2117 - mean_absolute_error: 17.0091 - acc: 0.0334 - val_loss: 498.7087 - val_mean_absolute_error: 14.5272 - val_acc: 0.0347
# Epoch 27/100
#  - 3s - loss: 618.9501 - mean_absolute_error: 16.8896 - acc: 0.0288 - val_loss: 506.0504 - val_mean_absolute_error: 15.0403 - val_acc: 0.0447
# Epoch 28/100
#  - 3s - loss: 620.7290 - mean_absolute_error: 17.0345 - acc: 0.0278 - val_loss: 542.8728 - val_mean_absolute_error: 16.4374 - val_acc: 0.0192
# Epoch 29/100
#  - 3s - loss: 609.9998 - mean_absolute_error: 16.6775 - acc: 0.0288 - val_loss: 486.4464 - val_mean_absolute_error: 14.5401 - val_acc: 0.0338
# Epoch 30/100
#  - 3s - loss: 602.1237 - mean_absolute_error: 16.7226 - acc: 0.0281 - val_loss: 537.1671 - val_mean_absolute_error: 15.3986 - val_acc: 0.0301
# Epoch 31/100
#  - 3s - loss: 591.0484 - mean_absolute_error: 16.5440 - acc: 0.0295 - val_loss: 538.6177 - val_mean_absolute_error: 17.9317 - val_acc: 0.0155
# Epoch 32/100
#  - 3s - loss: 598.5482 - mean_absolute_error: 16.7958 - acc: 0.0296 - val_loss: 453.3954 - val_mean_absolute_error: 14.5048 - val_acc: 0.0411
# Epoch 33/100
#  - 3s - loss: 551.9489 - mean_absolute_error: 16.0623 - acc: 0.0311 - val_loss: 456.5540 - val_mean_absolute_error: 14.2602 - val_acc: 0.0484
# Epoch 34/100
#  - 3s - loss: 560.4390 - mean_absolute_error: 16.1718 - acc: 0.0317 - val_loss: 454.4536 - val_mean_absolute_error: 14.3888 - val_acc: 0.0511
# Epoch 35/100
#  - 3s - loss: 528.2959 - mean_absolute_error: 15.8861 - acc: 0.0294 - val_loss: 466.4764 - val_mean_absolute_error: 14.0114 - val_acc: 0.0338
# Epoch 36/100
#  - 3s - loss: 540.2779 - mean_absolute_error: 15.7080 - acc: 0.0303 - val_loss: 493.0484 - val_mean_absolute_error: 14.3584 - val_acc: 0.0384
# Epoch 37/100
#  - 3s - loss: 511.0358 - mean_absolute_error: 15.3659 - acc: 0.0282 - val_loss: 550.3948 - val_mean_absolute_error: 14.8963 - val_acc: 0.0466
# Epoch 38/100
#  - 3s - loss: 509.0368 - mean_absolute_error: 15.3390 - acc: 0.0303 - val_loss: 395.0321 - val_mean_absolute_error: 12.9886 - val_acc: 0.0466
# Epoch 39/100
#  - 3s - loss: 498.9485 - mean_absolute_error: 15.2050 - acc: 0.0308 - val_loss: 410.3808 - val_mean_absolute_error: 13.4248 - val_acc: 0.0356
# Epoch 40/100
#  - 3s - loss: 456.4041 - mean_absolute_error: 14.6444 - acc: 0.0318 - val_loss: 374.5049 - val_mean_absolute_error: 12.2675 - val_acc: 0.0548
# Epoch 41/100
#  - 3s - loss: 480.0651 - mean_absolute_error: 14.8752 - acc: 0.0322 - val_loss: 430.7277 - val_mean_absolute_error: 13.9662 - val_acc: 0.0365
# Epoch 42/100
#  - 3s - loss: 507.5548 - mean_absolute_error: 15.2854 - acc: 0.0313 - val_loss: 401.6333 - val_mean_absolute_error: 13.5261 - val_acc: 0.0411
# Epoch 43/100
#  - 3s - loss: 495.9574 - mean_absolute_error: 15.1775 - acc: 0.0321 - val_loss: 405.1070 - val_mean_absolute_error: 13.3106 - val_acc: 0.0256
# Epoch 44/100
#  - 3s - loss: 459.0870 - mean_absolute_error: 14.5239 - acc: 0.0319 - val_loss: 361.0673 - val_mean_absolute_error: 12.0682 - val_acc: 0.0466
# Epoch 45/100
#  - 3s - loss: 431.6985 - mean_absolute_error: 14.1502 - acc: 0.0343 - val_loss: 499.4460 - val_mean_absolute_error: 14.7575 - val_acc: 0.0429
# Epoch 46/100
#  - 3s - loss: 474.2327 - mean_absolute_error: 14.8534 - acc: 0.0306 - val_loss: 416.3222 - val_mean_absolute_error: 13.9031 - val_acc: 0.0292
# Epoch 47/100
#  - 3s - loss: 430.6312 - mean_absolute_error: 14.2188 - acc: 0.0310 - val_loss: 323.1508 - val_mean_absolute_error: 11.7029 - val_acc: 0.0356
# Epoch 48/100
#  - 3s - loss: 436.8318 - mean_absolute_error: 14.2646 - acc: 0.0342 - val_loss: 369.8391 - val_mean_absolute_error: 12.4748 - val_acc: 0.0411
# Epoch 49/100
#  - 3s - loss: 441.8794 - mean_absolute_error: 14.3210 - acc: 0.0331 - val_loss: 362.1171 - val_mean_absolute_error: 12.2935 - val_acc: 0.0493
# Epoch 50/100
#  - 3s - loss: 407.7760 - mean_absolute_error: 13.7223 - acc: 0.0325 - val_loss: 329.2758 - val_mean_absolute_error: 12.1902 - val_acc: 0.0374
# Epoch 51/100
#  - 3s - loss: 413.1625 - mean_absolute_error: 14.0047 - acc: 0.0327 - val_loss: 420.7251 - val_mean_absolute_error: 12.6696 - val_acc: 0.0329
# Epoch 52/100
#  - 3s - loss: 412.1448 - mean_absolute_error: 13.9021 - acc: 0.0336 - val_loss: 309.0591 - val_mean_absolute_error: 12.0940 - val_acc: 0.0429
# Epoch 53/100
#  - 3s - loss: 383.3393 - mean_absolute_error: 13.4060 - acc: 0.0323 - val_loss: 406.2966 - val_mean_absolute_error: 13.8768 - val_acc: 0.0174
# Epoch 54/100
#  - 3s - loss: 414.1284 - mean_absolute_error: 13.8813 - acc: 0.0321 - val_loss: 380.9840 - val_mean_absolute_error: 12.7364 - val_acc: 0.0393
# Epoch 55/100
#  - 3s - loss: 380.0963 - mean_absolute_error: 13.4099 - acc: 0.0336 - val_loss: 357.5797 - val_mean_absolute_error: 12.0625 - val_acc: 0.0548
#  36%|███▌      | 5/14 [07:08<13:51, 92.42s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 2s - loss: 5423.0853 - mean_absolute_error: 57.2193 - acc: 0.0067 - val_loss: 3323.9872 - val_mean_absolute_error: 46.9356 - val_acc: 0.0037
# Epoch 2/100
#  - 1s - loss: 3014.4362 - mean_absolute_error: 43.7327 - acc: 0.0074 - val_loss: 1889.2676 - val_mean_absolute_error: 33.4698 - val_acc: 0.0082
# Epoch 3/100
#  - 1s - loss: 1727.1825 - mean_absolute_error: 31.7069 - acc: 0.0096 - val_loss: 1786.5114 - val_mean_absolute_error: 31.0370 - val_acc: 0.0128
# Epoch 4/100
#  - 1s - loss: 1662.7051 - mean_absolute_error: 30.5325 - acc: 0.0122 - val_loss: 1565.2011 - val_mean_absolute_error: 30.1032 - val_acc: 0.0137
# Epoch 5/100
#  - 1s - loss: 1612.3911 - mean_absolute_error: 30.0098 - acc: 0.0105 - val_loss: 1607.6742 - val_mean_absolute_error: 31.4261 - val_acc: 0.0128
# Epoch 6/100
#  - 1s - loss: 1484.0895 - mean_absolute_error: 28.4611 - acc: 0.0146 - val_loss: 1452.6280 - val_mean_absolute_error: 28.1386 - val_acc: 0.0155
# Epoch 7/100
#  - 1s - loss: 1481.0302 - mean_absolute_error: 28.2610 - acc: 0.0136 - val_loss: 1412.9304 - val_mean_absolute_error: 27.7238 - val_acc: 0.0064
# Epoch 8/100
#  - 1s - loss: 1336.5707 - mean_absolute_error: 26.6605 - acc: 0.0136 - val_loss: 1590.8150 - val_mean_absolute_error: 31.7203 - val_acc: 0.0119
# Epoch 9/100
#  - 1s - loss: 1369.6230 - mean_absolute_error: 26.9486 - acc: 0.0141 - val_loss: 1614.5792 - val_mean_absolute_error: 26.5365 - val_acc: 0.0146
# Epoch 10/100
#  - 1s - loss: 1335.0674 - mean_absolute_error: 26.3881 - acc: 0.0132 - val_loss: 1416.3460 - val_mean_absolute_error: 26.1456 - val_acc: 0.0091
# Epoch 11/100
#  - 1s - loss: 1231.0253 - mean_absolute_error: 25.2046 - acc: 0.0155 - val_loss: 1195.8889 - val_mean_absolute_error: 24.4468 - val_acc: 0.0137
# Epoch 12/100
#  - 1s - loss: 1206.4702 - mean_absolute_error: 25.1461 - acc: 0.0124 - val_loss: 1209.7051 - val_mean_absolute_error: 24.8262 - val_acc: 0.0155
# Epoch 13/100
#  - 1s - loss: 1152.9504 - mean_absolute_error: 24.1560 - acc: 0.0184 - val_loss: 1205.1883 - val_mean_absolute_error: 22.8393 - val_acc: 0.0155
# Epoch 14/100
#  - 1s - loss: 1215.1728 - mean_absolute_error: 25.1333 - acc: 0.0140 - val_loss: 1088.5092 - val_mean_absolute_error: 22.5369 - val_acc: 0.0201
# Epoch 15/100
#  - 1s - loss: 1090.5941 - mean_absolute_error: 23.1190 - acc: 0.0163 - val_loss: 1215.9708 - val_mean_absolute_error: 27.5530 - val_acc: 0.0027
# Epoch 16/100
#  - 1s - loss: 1141.1941 - mean_absolute_error: 24.0567 - acc: 0.0138 - val_loss: 977.1368 - val_mean_absolute_error: 20.7782 - val_acc: 0.0237
# Epoch 17/100
#  - 1s - loss: 1102.8614 - mean_absolute_error: 23.6117 - acc: 0.0143 - val_loss: 992.4277 - val_mean_absolute_error: 21.0651 - val_acc: 0.0219
# Epoch 18/100
#  - 1s - loss: 1008.0209 - mean_absolute_error: 22.1854 - acc: 0.0182 - val_loss: 910.5206 - val_mean_absolute_error: 21.2263 - val_acc: 0.0219
# Epoch 19/100
#  - 1s - loss: 1055.1724 - mean_absolute_error: 23.1909 - acc: 0.0179 - val_loss: 949.8840 - val_mean_absolute_error: 20.2869 - val_acc: 0.0274
# Epoch 20/100
#  - 1s - loss: 967.3665 - mean_absolute_error: 21.8669 - acc: 0.0172 - val_loss: 910.7591 - val_mean_absolute_error: 21.0658 - val_acc: 0.0219
# Epoch 21/100
#  - 1s - loss: 998.1997 - mean_absolute_error: 22.3989 - acc: 0.0181 - val_loss: 855.3359 - val_mean_absolute_error: 19.4131 - val_acc: 0.0192
# Epoch 22/100
#  - 1s - loss: 961.9925 - mean_absolute_error: 21.6089 - acc: 0.0203 - val_loss: 848.2384 - val_mean_absolute_error: 19.5104 - val_acc: 0.0283
# Epoch 23/100
#  - 1s - loss: 952.5283 - mean_absolute_error: 21.5713 - acc: 0.0202 - val_loss: 881.6920 - val_mean_absolute_error: 20.6584 - val_acc: 0.0210
# Epoch 24/100
#  - 1s - loss: 948.4400 - mean_absolute_error: 21.7151 - acc: 0.0197 - val_loss: 848.8038 - val_mean_absolute_error: 19.3487 - val_acc: 0.0247
# Epoch 25/100
#  - 1s - loss: 914.7221 - mean_absolute_error: 20.9813 - acc: 0.0184 - val_loss: 811.6416 - val_mean_absolute_error: 20.0320 - val_acc: 0.0155
# Epoch 26/100
#  - 1s - loss: 950.9843 - mean_absolute_error: 21.5435 - acc: 0.0215 - val_loss: 788.7024 - val_mean_absolute_error: 18.9157 - val_acc: 0.0228
# Epoch 27/100
#  - 1s - loss: 916.7091 - mean_absolute_error: 21.1926 - acc: 0.0205 - val_loss: 801.2023 - val_mean_absolute_error: 19.5991 - val_acc: 0.0219
# Epoch 28/100
#  - 1s - loss: 935.0532 - mean_absolute_error: 21.4999 - acc: 0.0193 - val_loss: 898.3879 - val_mean_absolute_error: 21.0977 - val_acc: 0.0183
# Epoch 29/100
#  - 1s - loss: 894.1214 - mean_absolute_error: 20.7019 - acc: 0.0188 - val_loss: 810.3188 - val_mean_absolute_error: 19.8271 - val_acc: 0.0201
# Epoch 30/100
#  - 1s - loss: 887.0288 - mean_absolute_error: 20.6439 - acc: 0.0229 - val_loss: 827.2419 - val_mean_absolute_error: 20.8441 - val_acc: 0.0128
# Epoch 31/100
#  - 1s - loss: 900.8983 - mean_absolute_error: 20.8569 - acc: 0.0201 - val_loss: 815.9831 - val_mean_absolute_error: 21.0087 - val_acc: 0.0082
# Epoch 32/100
#  - 1s - loss: 887.2344 - mean_absolute_error: 20.7236 - acc: 0.0206 - val_loss: 820.4493 - val_mean_absolute_error: 20.2769 - val_acc: 0.0137
# Epoch 33/100
#  - 1s - loss: 888.0713 - mean_absolute_error: 20.8388 - acc: 0.0203 - val_loss: 843.5728 - val_mean_absolute_error: 21.8250 - val_acc: 0.0164
# Epoch 34/100
#  - 1s - loss: 872.3507 - mean_absolute_error: 20.5174 - acc: 0.0201 - val_loss: 741.4684 - val_mean_absolute_error: 18.3013 - val_acc: 0.0256
# Epoch 35/100
#  - 1s - loss: 872.9123 - mean_absolute_error: 20.4415 - acc: 0.0221 - val_loss: 1299.7624 - val_mean_absolute_error: 29.9365 - val_acc: 0.0073
# Epoch 36/100
#  - 1s - loss: 877.1121 - mean_absolute_error: 20.4489 - acc: 0.0200 - val_loss: 752.9393 - val_mean_absolute_error: 18.2187 - val_acc: 0.0265
# Epoch 37/100
#  - 1s - loss: 849.6885 - mean_absolute_error: 20.0841 - acc: 0.0194 - val_loss: 867.8252 - val_mean_absolute_error: 21.6840 - val_acc: 0.0256
#  43%|████▎     | 6/14 [07:57<10:35, 79.38s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 5s - loss: 33.7303 - mean_absolute_error: 34.4128 - acc: 0.0136 - val_loss: 26.4352 - val_mean_absolute_error: 27.1114 - val_acc: 0.0201
# Epoch 2/100
#  - 4s - loss: 20.9678 - mean_absolute_error: 21.6431 - acc: 0.0200 - val_loss: 17.2068 - val_mean_absolute_error: 17.8746 - val_acc: 0.0274
# Epoch 3/100
#  - 4s - loss: 19.0880 - mean_absolute_error: 19.7596 - acc: 0.0246 - val_loss: 20.1138 - val_mean_absolute_error: 20.7955 - val_acc: 0.0128
# Epoch 4/100
#  - 4s - loss: 17.8416 - mean_absolute_error: 18.5108 - acc: 0.0282 - val_loss: 18.2321 - val_mean_absolute_error: 18.9009 - val_acc: 0.0292
# Epoch 5/100
#  - 4s - loss: 17.2218 - mean_absolute_error: 17.8889 - acc: 0.0332 - val_loss: 15.3383 - val_mean_absolute_error: 15.9951 - val_acc: 0.0411
# Epoch 6/100
#  - 4s - loss: 16.8338 - mean_absolute_error: 17.4995 - acc: 0.0329 - val_loss: 17.0643 - val_mean_absolute_error: 17.7251 - val_acc: 0.0429
# Epoch 7/100
#  - 4s - loss: 16.7006 - mean_absolute_error: 17.3664 - acc: 0.0325 - val_loss: 14.9083 - val_mean_absolute_error: 15.5795 - val_acc: 0.0228
# Epoch 8/100
#  - 4s - loss: 16.4359 - mean_absolute_error: 17.0979 - acc: 0.0393 - val_loss: 16.4763 - val_mean_absolute_error: 17.1524 - val_acc: 0.0164
# Epoch 9/100
#  - 4s - loss: 16.6353 - mean_absolute_error: 17.2998 - acc: 0.0349 - val_loss: 15.4397 - val_mean_absolute_error: 16.1092 - val_acc: 0.0247
# Epoch 10/100
#  - 4s - loss: 16.3160 - mean_absolute_error: 16.9808 - acc: 0.0319 - val_loss: 14.8135 - val_mean_absolute_error: 15.4658 - val_acc: 0.0447
# Epoch 11/100
#  - 4s - loss: 16.1009 - mean_absolute_error: 16.7646 - acc: 0.0342 - val_loss: 14.3207 - val_mean_absolute_error: 14.9736 - val_acc: 0.0493
# Epoch 12/100
#  - 4s - loss: 15.8803 - mean_absolute_error: 16.5428 - acc: 0.0371 - val_loss: 14.6592 - val_mean_absolute_error: 15.3122 - val_acc: 0.0530
# Epoch 13/100
#  - 4s - loss: 15.9664 - mean_absolute_error: 16.6302 - acc: 0.0355 - val_loss: 14.5309 - val_mean_absolute_error: 15.1984 - val_acc: 0.0274
# Epoch 14/100
#  - 4s - loss: 15.9041 - mean_absolute_error: 16.5660 - acc: 0.0382 - val_loss: 14.1175 - val_mean_absolute_error: 14.7695 - val_acc: 0.0548
# Epoch 15/100
#  - 4s - loss: 15.8927 - mean_absolute_error: 16.5549 - acc: 0.0391 - val_loss: 15.9621 - val_mean_absolute_error: 16.6315 - val_acc: 0.0292
# Epoch 16/100
#  - 4s - loss: 15.9156 - mean_absolute_error: 16.5779 - acc: 0.0392 - val_loss: 14.5760 - val_mean_absolute_error: 15.2458 - val_acc: 0.0311
# Epoch 17/100
#  - 4s - loss: 15.6674 - mean_absolute_error: 16.3295 - acc: 0.0369 - val_loss: 15.1945 - val_mean_absolute_error: 15.8629 - val_acc: 0.0283
# Epoch 18/100
#  - 4s - loss: 15.5104 - mean_absolute_error: 16.1715 - acc: 0.0370 - val_loss: 13.5883 - val_mean_absolute_error: 14.2540 - val_acc: 0.0274
# Epoch 19/100
#  - 4s - loss: 15.5259 - mean_absolute_error: 16.1860 - acc: 0.0402 - val_loss: 15.2791 - val_mean_absolute_error: 15.9452 - val_acc: 0.0338
# Epoch 20/100
#  - 4s - loss: 15.6400 - mean_absolute_error: 16.3018 - acc: 0.0394 - val_loss: 13.7479 - val_mean_absolute_error: 14.3942 - val_acc: 0.0548
# Epoch 21/100
#  - 4s - loss: 15.5157 - mean_absolute_error: 16.1774 - acc: 0.0376 - val_loss: 13.1591 - val_mean_absolute_error: 13.8161 - val_acc: 0.0466
# Epoch 22/100
#  - 4s - loss: 15.1657 - mean_absolute_error: 15.8262 - acc: 0.0402 - val_loss: 14.4389 - val_mean_absolute_error: 15.0853 - val_acc: 0.0594
# Epoch 23/100
#  - 4s - loss: 15.1873 - mean_absolute_error: 15.8491 - acc: 0.0388 - val_loss: 14.3750 - val_mean_absolute_error: 15.0368 - val_acc: 0.0384
# Epoch 24/100
#  - 4s - loss: 15.1605 - mean_absolute_error: 15.8201 - acc: 0.0415 - val_loss: 13.4279 - val_mean_absolute_error: 14.0765 - val_acc: 0.0584
# Epoch 25/100
#  - 4s - loss: 15.2395 - mean_absolute_error: 15.9001 - acc: 0.0388 - val_loss: 13.7479 - val_mean_absolute_error: 14.3945 - val_acc: 0.0594
# Epoch 26/100
#  - 4s - loss: 15.1103 - mean_absolute_error: 15.7696 - acc: 0.0409 - val_loss: 13.3787 - val_mean_absolute_error: 14.0243 - val_acc: 0.0612
# Epoch 27/100
#  - 4s - loss: 14.9786 - mean_absolute_error: 15.6387 - acc: 0.0395 - val_loss: 15.2551 - val_mean_absolute_error: 15.9208 - val_acc: 0.0393
# Epoch 28/100
#  - 4s - loss: 14.8787 - mean_absolute_error: 15.5387 - acc: 0.0410 - val_loss: 13.3024 - val_mean_absolute_error: 13.9594 - val_acc: 0.0429
# Epoch 29/100
#  - 4s - loss: 14.8011 - mean_absolute_error: 15.4610 - acc: 0.0418 - val_loss: 14.7263 - val_mean_absolute_error: 15.3821 - val_acc: 0.0447
# Epoch 30/100
#  - 4s - loss: 14.7230 - mean_absolute_error: 15.3848 - acc: 0.0374 - val_loss: 12.8766 - val_mean_absolute_error: 13.5269 - val_acc: 0.0539
# Epoch 31/100
#  - 4s - loss: 14.7854 - mean_absolute_error: 15.4439 - acc: 0.0440 - val_loss: 13.2831 - val_mean_absolute_error: 13.9402 - val_acc: 0.0530
# Epoch 32/100
#  - 4s - loss: 14.7435 - mean_absolute_error: 15.4040 - acc: 0.0412 - val_loss: 12.9062 - val_mean_absolute_error: 13.5584 - val_acc: 0.0521
# Epoch 33/100
#  - 4s - loss: 14.7860 - mean_absolute_error: 15.4469 - acc: 0.0397 - val_loss: 12.6253 - val_mean_absolute_error: 13.2790 - val_acc: 0.0475
# Epoch 34/100
#  - 4s - loss: 14.5196 - mean_absolute_error: 15.1787 - acc: 0.0420 - val_loss: 12.6032 - val_mean_absolute_error: 13.2529 - val_acc: 0.0521
# Epoch 35/100
#  - 4s - loss: 14.4655 - mean_absolute_error: 15.1252 - acc: 0.0421 - val_loss: 14.4060 - val_mean_absolute_error: 15.0723 - val_acc: 0.0311
# Epoch 36/100
#  - 4s - loss: 14.6090 - mean_absolute_error: 15.2679 - acc: 0.0433 - val_loss: 13.1557 - val_mean_absolute_error: 13.8135 - val_acc: 0.0438
# Epoch 37/100
#  - 5s - loss: 14.5404 - mean_absolute_error: 15.2007 - acc: 0.0404 - val_loss: 14.4757 - val_mean_absolute_error: 15.1396 - val_acc: 0.0356
# Epoch 38/100
#  - 5s - loss: 14.5759 - mean_absolute_error: 15.2375 - acc: 0.0377 - val_loss: 13.0388 - val_mean_absolute_error: 13.6942 - val_acc: 0.0493
# Epoch 39/100
#  - 4s - loss: 14.2854 - mean_absolute_error: 14.9436 - acc: 0.0417 - val_loss: 13.0194 - val_mean_absolute_error: 13.6780 - val_acc: 0.0374
# Epoch 40/100
#  - 4s - loss: 14.3247 - mean_absolute_error: 14.9849 - acc: 0.0397 - val_loss: 12.6412 - val_mean_absolute_error: 13.2955 - val_acc: 0.0466
# Epoch 41/100
#  - 4s - loss: 14.1375 - mean_absolute_error: 14.7959 - acc: 0.0419 - val_loss: 12.3411 - val_mean_absolute_error: 12.9898 - val_acc: 0.0530
#  50%|█████     | 7/14 [10:54<12:39, 108.54s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 5s - loss: 32.3412 - mean_absolute_error: 33.0238 - acc: 0.0126 - val_loss: 27.9532 - val_mean_absolute_error: 28.6388 - val_acc: 0.0091
# Epoch 2/100
#  - 4s - loss: 25.8838 - mean_absolute_error: 26.5627 - acc: 0.0173 - val_loss: 26.4896 - val_mean_absolute_error: 27.1662 - val_acc: 0.0183
# Epoch 3/100
#  - 4s - loss: 24.0090 - mean_absolute_error: 24.6846 - acc: 0.0221 - val_loss: 23.6924 - val_mean_absolute_error: 24.3631 - val_acc: 0.0274
# Epoch 4/100
#  - 4s - loss: 22.4104 - mean_absolute_error: 23.0839 - acc: 0.0239 - val_loss: 23.7870 - val_mean_absolute_error: 24.4565 - val_acc: 0.0329
# Epoch 5/100
#  - 4s - loss: 21.3997 - mean_absolute_error: 22.0723 - acc: 0.0235 - val_loss: 25.9795 - val_mean_absolute_error: 26.6583 - val_acc: 0.0192
# Epoch 6/100
#  - 4s - loss: 20.5863 - mean_absolute_error: 21.2553 - acc: 0.0310 - val_loss: 18.3523 - val_mean_absolute_error: 19.0185 - val_acc: 0.0356
# Epoch 7/100
#  - 4s - loss: 19.4420 - mean_absolute_error: 20.1096 - acc: 0.0311 - val_loss: 16.8474 - val_mean_absolute_error: 17.5098 - val_acc: 0.0365
# Epoch 8/100
#  - 4s - loss: 19.0194 - mean_absolute_error: 19.6864 - acc: 0.0319 - val_loss: 30.1822 - val_mean_absolute_error: 30.8629 - val_acc: 0.0137
# Epoch 9/100
#  - 4s - loss: 18.3624 - mean_absolute_error: 19.0263 - acc: 0.0371 - val_loss: 17.2735 - val_mean_absolute_error: 17.9261 - val_acc: 0.0530
# Epoch 10/100
#  - 4s - loss: 18.0586 - mean_absolute_error: 18.7222 - acc: 0.0358 - val_loss: 15.7914 - val_mean_absolute_error: 16.4502 - val_acc: 0.0402
# Epoch 11/100
#  - 4s - loss: 17.6563 - mean_absolute_error: 18.3191 - acc: 0.0377 - val_loss: 15.1989 - val_mean_absolute_error: 15.8515 - val_acc: 0.0484
# Epoch 12/100
#  - 4s - loss: 17.3552 - mean_absolute_error: 18.0167 - acc: 0.0390 - val_loss: 16.7077 - val_mean_absolute_error: 17.3704 - val_acc: 0.0393
# Epoch 13/100
#  - 4s - loss: 17.8633 - mean_absolute_error: 18.5277 - acc: 0.0363 - val_loss: 15.3085 - val_mean_absolute_error: 15.9651 - val_acc: 0.0438
# Epoch 14/100
#  - 4s - loss: 16.7731 - mean_absolute_error: 17.4359 - acc: 0.0365 - val_loss: 19.5051 - val_mean_absolute_error: 20.1697 - val_acc: 0.0365
# Epoch 15/100
#  - 4s - loss: 17.0402 - mean_absolute_error: 17.7053 - acc: 0.0349 - val_loss: 22.6287 - val_mean_absolute_error: 23.3069 - val_acc: 0.0164
# Epoch 16/100
#  - 4s - loss: 16.8013 - mean_absolute_error: 17.4641 - acc: 0.0380 - val_loss: 20.7796 - val_mean_absolute_error: 21.4425 - val_acc: 0.0356
# Epoch 17/100
#  - 4s - loss: 16.4054 - mean_absolute_error: 17.0688 - acc: 0.0364 - val_loss: 14.7039 - val_mean_absolute_error: 15.3597 - val_acc: 0.0447
# Epoch 18/100
#  - 4s - loss: 16.0520 - mean_absolute_error: 16.7155 - acc: 0.0368 - val_loss: 21.0521 - val_mean_absolute_error: 21.7299 - val_acc: 0.0201
# Epoch 19/100
#  - 4s - loss: 16.3955 - mean_absolute_error: 17.0581 - acc: 0.0373 - val_loss: 17.8508 - val_mean_absolute_error: 18.5269 - val_acc: 0.0183
# Epoch 20/100
#  - 4s - loss: 15.8278 - mean_absolute_error: 16.4918 - acc: 0.0356 - val_loss: 17.7149 - val_mean_absolute_error: 18.3749 - val_acc: 0.0429
# Epoch 21/100
#  - 4s - loss: 15.6637 - mean_absolute_error: 16.3255 - acc: 0.0375 - val_loss: 14.4403 - val_mean_absolute_error: 15.1021 - val_acc: 0.0374
# Epoch 22/100
#  - 4s - loss: 15.4235 - mean_absolute_error: 16.0842 - acc: 0.0394 - val_loss: 16.9005 - val_mean_absolute_error: 17.5644 - val_acc: 0.0365
# Epoch 23/100
#  - 4s - loss: 15.6183 - mean_absolute_error: 16.2801 - acc: 0.0393 - val_loss: 14.6723 - val_mean_absolute_error: 15.3358 - val_acc: 0.0411
# Epoch 24/100
# ...
# Epoch 42/100
#  - 3s - loss: 14.4955 - mean_absolute_error: 15.1575 - acc: 0.0379 - val_loss: 12.2949 - val_mean_absolute_error: 12.9438 - val_acc: 0.0621
#  79%|███████▊  | 11/14 [18:30<05:50, 116.68s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 5s - loss: 3320.9431 - mean_absolute_error: 45.6662 - acc: 0.0070 - val_loss: 1745.0690 - val_mean_absolute_error: 33.0654 - val_acc: 0.0100
# Epoch 2/100
#  - 4s - loss: 1403.9024 - mean_absolute_error: 27.4556 - acc: 0.0131 - val_loss: 1265.9291 - val_mean_absolute_error: 26.1027 - val_acc: 0.0228
# Epoch 3/100
#  - 4s - loss: 1149.2722 - mean_absolute_error: 24.2596 - acc: 0.0182 - val_loss: 1033.6536 - val_mean_absolute_error: 23.0775 - val_acc: 0.0183
# Epoch 4/100
#  - 4s - loss: 1014.4106 - mean_absolute_error: 22.6845 - acc: 0.0181 - val_loss: 922.3241 - val_mean_absolute_error: 22.5267 - val_acc: 0.0073
# Epoch 5/100
#  - 4s - loss: 937.9676 - mean_absolute_error: 21.6859 - acc: 0.0163 - val_loss: 792.7070 - val_mean_absolute_error: 19.8361 - val_acc: 0.0210
# Epoch 6/100
#  - 4s - loss: 909.5128 - mean_absolute_error: 21.3494 - acc: 0.0175 - val_loss: 767.6908 - val_mean_absolute_error: 18.8186 - val_acc: 0.0183
# Epoch 7/100
#  - 4s - loss: 881.2343 - mean_absolute_error: 20.9527 - acc: 0.0191 - val_loss: 741.9824 - val_mean_absolute_error: 19.0641 - val_acc: 0.0274
# Epoch 8/100
#  - 4s - loss: 854.8705 - mean_absolute_error: 20.5519 - acc: 0.0202 - val_loss: 770.6554 - val_mean_absolute_error: 18.1147 - val_acc: 0.0393
# Epoch 9/100
#  - 4s - loss: 833.5707 - mean_absolute_error: 20.3254 - acc: 0.0194 - val_loss: 734.2237 - val_mean_absolute_error: 18.9271 - val_acc: 0.0320
# Epoch 10/100
#  - 4s - loss: 809.5550 - mean_absolute_error: 20.1689 - acc: 0.0194 - val_loss: 695.7608 - val_mean_absolute_error: 18.4260 - val_acc: 0.0183
# Epoch 11/100
#  - 4s - loss: 791.7877 - mean_absolute_error: 19.8565 - acc: 0.0213 - val_loss: 733.5046 - val_mean_absolute_error: 19.6259 - val_acc: 0.0210
# Epoch 12/100
#  - 4s - loss: 789.4378 - mean_absolute_error: 19.6490 - acc: 0.0205 - val_loss: 644.0163 - val_mean_absolute_error: 18.1132 - val_acc: 0.0183
# Epoch 13/100
#  - 4s - loss: 776.4112 - mean_absolute_error: 19.5725 - acc: 0.0222 - val_loss: 638.4076 - val_mean_absolute_error: 16.8330 - val_acc: 0.0338
# Epoch 14/100
#  - 4s - loss: 763.4772 - mean_absolute_error: 19.2381 - acc: 0.0196 - val_loss: 649.5627 - val_mean_absolute_error: 17.7098 - val_acc: 0.0228
# Epoch 15/100
#  - 4s - loss: 741.3490 - mean_absolute_error: 18.8405 - acc: 0.0239 - val_loss: 669.0609 - val_mean_absolute_error: 17.8778 - val_acc: 0.0356
# Epoch 16/100
#  - 4s - loss: 735.0656 - mean_absolute_error: 18.7163 - acc: 0.0219 - val_loss: 672.0622 - val_mean_absolute_error: 18.7079 - val_acc: 0.0402
# Epoch 17/100
#  - 4s - loss: 734.3969 - mean_absolute_error: 18.7454 - acc: 0.0256 - val_loss: 641.9554 - val_mean_absolute_error: 16.8050 - val_acc: 0.0365
# Epoch 18/100
#  - 4s - loss: 719.9699 - mean_absolute_error: 18.4009 - acc: 0.0226 - val_loss: 679.8227 - val_mean_absolute_error: 17.4303 - val_acc: 0.0237
# Epoch 19/100
#  - 4s - loss: 690.0546 - mean_absolute_error: 17.9624 - acc: 0.0248 - val_loss: 580.5155 - val_mean_absolute_error: 16.1967 - val_acc: 0.0365
# Epoch 20/100
#  - 4s - loss: 675.1498 - mean_absolute_error: 17.8113 - acc: 0.0230 - val_loss: 571.5466 - val_mean_absolute_error: 15.0861 - val_acc: 0.0320
# Epoch 21/100
#  - 4s - loss: 656.7718 - mean_absolute_error: 17.5290 - acc: 0.0230 - val_loss: 623.7465 - val_mean_absolute_error: 16.3570 - val_acc: 0.0301
# Epoch 22/100
#  - 4s - loss: 625.6705 - mean_absolute_error: 17.2933 - acc: 0.0236 - val_loss: 577.7452 - val_mean_absolute_error: 16.8977 - val_acc: 0.0210
# Epoch 23/100
#  - 4s - loss: 606.7097 - mean_absolute_error: 17.0151 - acc: 0.0261 - val_loss: 524.6129 - val_mean_absolute_error: 16.1986 - val_acc: 0.0265
# Epoch 24/100
#  - 4s - loss: 597.4268 - mean_absolute_error: 16.7596 - acc: 0.0249 - val_loss: 548.1375 - val_mean_absolute_error: 16.1688 - val_acc: 0.0438
# Epoch 25/100
#  - 4s - loss: 555.1807 - mean_absolute_error: 16.3234 - acc: 0.0274 - val_loss: 646.4288 - val_mean_absolute_error: 16.9321 - val_acc: 0.0210
# Epoch 26/100
#  - 4s - loss: 530.8373 - mean_absolute_error: 16.0825 - acc: 0.0261 - val_loss: 413.0297 - val_mean_absolute_error: 14.1232 - val_acc: 0.0447
# Epoch 27/100
#  - 4s - loss: 527.2998 - mean_absolute_error: 16.0451 - acc: 0.0278 - val_loss: 616.5055 - val_mean_absolute_error: 17.8054 - val_acc: 0.0219
# Epoch 28/100
#  - 4s - loss: 497.8196 - mean_absolute_error: 15.6511 - acc: 0.0273 - val_loss: 414.0460 - val_mean_absolute_error: 14.0171 - val_acc: 0.0429
# Epoch 29/100
#  - 4s - loss: 465.1850 - mean_absolute_error: 15.3563 - acc: 0.0281 - val_loss: 552.2362 - val_mean_absolute_error: 17.6933 - val_acc: 0.0164
# Epoch 30/100
#  - 4s - loss: 431.6881 - mean_absolute_error: 14.7992 - acc: 0.0291 - val_loss: 322.2818 - val_mean_absolute_error: 12.5720 - val_acc: 0.0493
# Epoch 31/100
#  - 4s - loss: 430.7908 - mean_absolute_error: 14.8233 - acc: 0.0286 - val_loss: 339.9769 - val_mean_absolute_error: 12.8862 - val_acc: 0.0429
# Epoch 32/100
#  - 4s - loss: 412.6202 - mean_absolute_error: 14.4518 - acc: 0.0271 - val_loss: 315.9022 - val_mean_absolute_error: 12.3915 - val_acc: 0.0466
# Epoch 33/100
#  - 4s - loss: 396.2805 - mean_absolute_error: 14.3015 - acc: 0.0314 - val_loss: 384.5843 - val_mean_absolute_error: 14.1407 - val_acc: 0.0219
# Epoch 34/100
#  - 4s - loss: 367.2755 - mean_absolute_error: 13.7694 - acc: 0.0308 - val_loss: 424.8281 - val_mean_absolute_error: 14.7881 - val_acc: 0.0228
# Epoch 35/100
#  - 5s - loss: 362.5762 - mean_absolute_error: 13.7087 - acc: 0.0326 - val_loss: 334.8211 - val_mean_absolute_error: 13.5866 - val_acc: 0.0219
# Epoch 36/100
#  - 4s - loss: 358.2800 - mean_absolute_error: 13.5717 - acc: 0.0331 - val_loss: 253.5057 - val_mean_absolute_error: 11.2888 - val_acc: 0.0301
# Epoch 37/100
#  - 4s - loss: 340.5307 - mean_absolute_error: 13.2626 - acc: 0.0329 - val_loss: 326.3255 - val_mean_absolute_error: 12.7753 - val_acc: 0.0338
# Epoch 38/100
#  - 4s - loss: 340.7976 - mean_absolute_error: 13.2902 - acc: 0.0321 - val_loss: 346.4333 - val_mean_absolute_error: 14.0165 - val_acc: 0.0237
# Epoch 39/100
#  - 4s - loss: 327.1745 - mean_absolute_error: 13.0715 - acc: 0.0310 - val_loss: 242.9715 - val_mean_absolute_error: 11.0839 - val_acc: 0.0402
# Epoch 40/100
#  - 4s - loss: 305.3841 - mean_absolute_error: 12.5509 - acc: 0.0351 - val_loss: 287.8039 - val_mean_absolute_error: 11.9399 - val_acc: 0.0301
# Epoch 41/100
#  - 4s - loss: 311.2002 - mean_absolute_error: 12.6089 - acc: 0.0318 - val_loss: 263.7860 - val_mean_absolute_error: 11.8682 - val_acc: 0.0374
# Epoch 42/100
#  - 4s - loss: 307.9368 - mean_absolute_error: 12.7111 - acc: 0.0332 - val_loss: 245.3576 - val_mean_absolute_error: 11.1353 - val_acc: 0.0320
# Epoch 43/100
#  - 4s - loss: 297.2267 - mean_absolute_error: 12.4954 - acc: 0.0308 - val_loss: 214.1700 - val_mean_absolute_error: 10.2987 - val_acc: 0.0484
# Epoch 44/100
#  - 4s - loss: 288.9020 - mean_absolute_error: 12.2496 - acc: 0.0365 - val_loss: 225.1811 - val_mean_absolute_error: 10.6175 - val_acc: 0.0365
# Epoch 45/100
#  - 4s - loss: 316.1554 - mean_absolute_error: 12.7199 - acc: 0.0335 - val_loss: 289.5167 - val_mean_absolute_error: 12.0517 - val_acc: 0.0420
#  86%|████████▌ | 12/14 [21:44<04:39, 139.95s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 2s - loss: 9285.5708 - mean_absolute_error: 77.8568 - acc: 0.0066 - val_loss: 7349.3252 - val_mean_absolute_error: 65.9848 - val_acc: 0.0073
# Epoch 2/100
#  - 1s - loss: 5912.7544 - mean_absolute_error: 58.6832 - acc: 0.0061 - val_loss: 4337.6644 - val_mean_absolute_error: 49.4292 - val_acc: 0.0073
# Epoch 3/100
#  - 1s - loss: 3746.2234 - mean_absolute_error: 47.5741 - acc: 0.0066 - val_loss: 3373.6891 - val_mean_absolute_error: 46.3824 - val_acc: 0.0046
# Epoch 4/100
#  - 1s - loss: 3323.7240 - mean_absolute_error: 46.3179 - acc: 0.0049 - val_loss: 3344.4208 - val_mean_absolute_error: 46.9727 - val_acc: 0.0037
# Epoch 5/100
#  - 1s - loss: 3312.9978 - mean_absolute_error: 46.4251 - acc: 0.0060 - val_loss: 3343.4130 - val_mean_absolute_error: 46.9299 - val_acc: 0.0037
# Epoch 6/100
#  - 1s - loss: 3312.9648 - mean_absolute_error: 46.3851 - acc: 0.0070 - val_loss: 3342.1685 - val_mean_absolute_error: 46.8436 - val_acc: 0.0046
# Epoch 7/100
#  - 1s - loss: 3312.3356 - mean_absolute_error: 46.3511 - acc: 0.0078 - val_loss: 3341.9761 - val_mean_absolute_error: 46.7730 - val_acc: 0.0064
# Epoch 8/100
#  - 1s - loss: 3316.1477 - mean_absolute_error: 46.3844 - acc: 0.0058 - val_loss: 3342.2984 - val_mean_absolute_error: 46.8572 - val_acc: 0.0046
# Epoch 9/100
#  - 1s - loss: 3309.0762 - mean_absolute_error: 46.3607 - acc: 0.0071 - val_loss: 3342.2999 - val_mean_absolute_error: 46.8574 - val_acc: 0.0046
# Epoch 10/100
#  - 1s - loss: 3323.3540 - mean_absolute_error: 46.4157 - acc: 0.0060 - val_loss: 3342.0761 - val_mean_absolute_error: 46.8316 - val_acc: 0.0046
# Epoch 11/100
#  - 1s - loss: 3327.2398 - mean_absolute_error: 46.4337 - acc: 0.0072 - val_loss: 3342.1598 - val_mean_absolute_error: 46.8426 - val_acc: 0.0046
# Epoch 12/100
#  - 1s - loss: 3315.7440 - mean_absolute_error: 46.3819 - acc: 0.0051 - val_loss: 3342.3784 - val_mean_absolute_error: 46.8648 - val_acc: 0.0046
# Epoch 13/100
#  - 1s - loss: 3313.4310 - mean_absolute_error: 46.3772 - acc: 0.0065 - val_loss: 3343.0916 - val_mean_absolute_error: 46.9133 - val_acc: 0.0037
# Epoch 14/100
#  - 1s - loss: 3311.8727 - mean_absolute_error: 46.3907 - acc: 0.0070 - val_loss: 3341.9586 - val_mean_absolute_error: 46.8051 - val_acc: 0.0046
# Epoch 15/100
#  - 1s - loss: 3323.9028 - mean_absolute_error: 46.5048 - acc: 0.0061 - val_loss: 3343.0014 - val_mean_absolute_error: 46.9083 - val_acc: 0.0046
# Epoch 16/100
#  - 1s - loss: 3311.6562 - mean_absolute_error: 46.3654 - acc: 0.0069 - val_loss: 3341.9458 - val_mean_absolute_error: 46.7881 - val_acc: 0.0064
#  93%|█████████▎| 13/14 [22:07<01:44, 104.97s/it]
# Train on 9846 samples, validate on 1095 samples
# Epoch 1/100
#  - 2s - loss: 4748.7363 - mean_absolute_error: 53.2382 - acc: 0.0056 - val_loss: 2015.8236 - val_mean_absolute_error: 31.8381 - val_acc: 0.0073
# Epoch 2/100
#  - 1s - loss: 1544.5216 - mean_absolute_error: 29.4831 - acc: 0.0128 - val_loss: 1484.5902 - val_mean_absolute_error: 29.1318 - val_acc: 0.0110
# Epoch 3/100
#  - 1s - loss: 1407.5442 - mean_absolute_error: 27.9123 - acc: 0.0152 - val_loss: 1492.4281 - val_mean_absolute_error: 28.2404 - val_acc: 0.0146
# Epoch 4/100
#  - 1s - loss: 1379.0758 - mean_absolute_error: 27.4990 - acc: 0.0172 - val_loss: 1382.1009 - val_mean_absolute_error: 27.5546 - val_acc: 0.0201
# Epoch 5/100
#  - 1s - loss: 1303.9067 - mean_absolute_error: 26.4459 - acc: 0.0156 - val_loss: 1328.7662 - val_mean_absolute_error: 26.4914 - val_acc: 0.0201
# Epoch 6/100
#  - 1s - loss: 1271.1697 - mean_absolute_error: 25.8803 - acc: 0.0159 - val_loss: 1310.4832 - val_mean_absolute_error: 25.7487 - val_acc: 0.0201
# Epoch 7/100
#  - 1s - loss: 1201.7089 - mean_absolute_error: 24.8633 - acc: 0.0167 - val_loss: 1182.5458 - val_mean_absolute_error: 24.6358 - val_acc: 0.0210
# Epoch 8/100
#  - 1s - loss: 1137.9051 - mean_absolute_error: 23.9026 - acc: 0.0170 - val_loss: 1080.6962 - val_mean_absolute_error: 22.8781 - val_acc: 0.0119
# Epoch 9/100
#  - 1s - loss: 1019.0012 - mean_absolute_error: 22.2191 - acc: 0.0229 - val_loss: 981.3978 - val_mean_absolute_error: 20.7489 - val_acc: 0.0256
# Epoch 10/100
#  - 1s - loss: 963.2115 - mean_absolute_error: 21.5661 - acc: 0.0196 - val_loss: 857.7811 - val_mean_absolute_error: 20.4752 - val_acc: 0.0201
# Epoch 11/100
#  - 1s - loss: 916.1012 - mean_absolute_error: 20.8918 - acc: 0.0219 - val_loss: 812.1932 - val_mean_absolute_error: 19.5049 - val_acc: 0.0228
# Epoch 12/100
#  - 1s - loss: 875.8974 - mean_absolute_error: 20.5375 - acc: 0.0213 - val_loss: 787.9540 - val_mean_absolute_error: 18.7514 - val_acc: 0.0228
# Epoch 13/100
#  - 1s - loss: 862.7523 - mean_absolute_error: 20.4871 - acc: 0.0207 - val_loss: 759.0366 - val_mean_absolute_error: 18.8734 - val_acc: 0.0237
# Epoch 14/100
#  - 1s - loss: 841.0976 - mean_absolute_error: 20.3126 - acc: 0.0216 - val_loss: 728.8517 - val_mean_absolute_error: 18.9580 - val_acc: 0.0219
# Epoch 15/100
#  - 1s - loss: 819.4676 - mean_absolute_error: 20.0281 - acc: 0.0219 - val_loss: 714.5836 - val_mean_absolute_error: 18.4997 - val_acc: 0.0365
# Epoch 16/100
#  - 1s - loss: 819.8780 - mean_absolute_error: 20.0274 - acc: 0.0191 - val_loss: 694.1518 - val_mean_absolute_error: 18.1341 - val_acc: 0.0256
# Epoch 17/100
#  - 1s - loss: 793.4011 - mean_absolute_error: 19.7619 - acc: 0.0182 - val_loss: 696.2337 - val_mean_absolute_error: 18.5304 - val_acc: 0.0201
# Epoch 18/100
#  - 1s - loss: 788.6038 - mean_absolute_error: 19.6476 - acc: 0.0209 - val_loss: 748.5936 - val_mean_absolute_error: 20.3534 - val_acc: 0.0247
# Epoch 19/100
#  - 1s - loss: 775.8624 - mean_absolute_error: 19.5253 - acc: 0.0226 - val_loss: 699.9996 - val_mean_absolute_error: 18.1056 - val_acc: 0.0283
# Epoch 20/100
#  - 1s - loss: 771.4719 - mean_absolute_error: 19.4141 - acc: 0.0202 - val_loss: 671.6678 - val_mean_absolute_error: 17.7162 - val_acc: 0.0192
# Epoch 21/100
#  - 1s - loss: 768.1447 - mean_absolute_error: 19.4652 - acc: 0.0211 - val_loss: 675.3224 - val_mean_absolute_error: 17.4701 - val_acc: 0.0374
# Epoch 22/100
#  - 1s - loss: 751.4385 - mean_absolute_error: 19.0580 - acc: 0.0213 - val_loss: 675.8962 - val_mean_absolute_error: 18.4515 - val_acc: 0.0146
# Epoch 23/100
#  - 1s - loss: 766.1484 - mean_absolute_error: 19.2671 - acc: 0.0209 - val_loss: 656.9360 - val_mean_absolute_error: 17.5628 - val_acc: 0.0393
# Epoch 24/100
#  - 1s - loss: 761.8215 - mean_absolute_error: 19.2609 - acc: 0.0209 - val_loss: 709.6049 - val_mean_absolute_error: 17.3812 - val_acc: 0.0265
# Epoch 25/100
#  - 1s - loss: 750.6982 - mean_absolute_error: 18.9989 - acc: 0.0193 - val_loss: 656.7603 - val_mean_absolute_error: 17.7575 - val_acc: 0.0256
# Epoch 26/100
#  - 1s - loss: 748.6765 - mean_absolute_error: 19.0164 - acc: 0.0223 - val_loss: 708.7234 - val_mean_absolute_error: 17.4673 - val_acc: 0.0374
# Epoch 27/100
#  - 1s - loss: 740.5090 - mean_absolute_error: 18.9511 - acc: 0.0207 - val_loss: 635.5140 - val_mean_absolute_error: 17.3152 - val_acc: 0.0256
# Epoch 28/100
#  - 1s - loss: 733.5832 - mean_absolute_error: 18.6988 - acc: 0.0228 - val_loss: 629.2117 - val_mean_absolute_error: 17.0864 - val_acc: 0.0201
# Epoch 29/100
#  - 1s - loss: 729.9925 - mean_absolute_error: 18.6780 - acc: 0.0225 - val_loss: 671.9324 - val_mean_absolute_error: 17.9589 - val_acc: 0.0237
# Epoch 30/100
#  - 1s - loss: 722.8061 - mean_absolute_error: 18.6024 - acc: 0.0243 - val_loss: 642.6478 - val_mean_absolute_error: 17.3348 - val_acc: 0.0329
# Epoch 31/100
#  - 1s - loss: 718.3000 - mean_absolute_error: 18.4525 - acc: 0.0238 - val_loss: 650.6432 - val_mean_absolute_error: 17.6920 - val_acc: 0.0228
# Epoch 32/100
#  - 1s - loss: 719.6999 - mean_absolute_error: 18.4908 - acc: 0.0201 - val_loss: 653.7265 - val_mean_absolute_error: 17.8038 - val_acc: 0.0247
# Epoch 33/100
#  - 1s - loss: 707.3496 - mean_absolute_error: 18.3553 - acc: 0.0220 - val_loss: 664.7349 - val_mean_absolute_error: 17.2142 - val_acc: 0.0201
# Epoch 34/100
#  - 1s - loss: 690.6241 - mean_absolute_error: 18.1363 - acc: 0.0228 - val_loss: 622.1764 - val_mean_absolute_error: 16.8648 - val_acc: 0.0301
# Epoch 35/100
#  - 1s - loss: 713.4504 - mean_absolute_error: 18.3786 - acc: 0.0220 - val_loss: 716.3189 - val_mean_absolute_error: 18.4036 - val_acc: 0.0201
# Epoch 36/100
#  - 1s - loss: 711.2752 - mean_absolute_error: 18.2311 - acc: 0.0216 - val_loss: 644.7845 - val_mean_absolute_error: 17.0320 - val_acc: 0.0256
# Epoch 37/100
#  - 1s - loss: 696.2978 - mean_absolute_error: 18.0081 - acc: 0.0245 - val_loss: 652.8428 - val_mean_absolute_error: 16.9153 - val_acc: 0.0329
# Epoch 38/100
#  - 1s - loss: 689.1135 - mean_absolute_error: 17.9770 - acc: 0.0247 - val_loss: 600.1737 - val_mean_absolute_error: 16.4688 - val_acc: 0.0301
# 100%|██████████| 14/14 [23:05<00:00, 90.78s/it]

# %% [markdown]
# TESTING RESULTS

# %%
p=ta.Predict(scan_object)
e=ta.Evaluate(scan_object)

# %%
r=ta.Reporting('030519215433_.csv')

# %%
r.best_params()
# Out:
# array([[13.661055597975919, 15.443959118170685, 'logcosh', 'Nadam', 3,
#         'tanh', 32, 0],
#        [12.94378938805567, 15.045963096928599, 'logcosh', 'Adam', 5,
#         'tanh', 32, 1],
#        [12.98980499163066, 14.795931387790306, 'logcosh', 'Nadam', 3,
#         'tanh', 16, 2],
#        [15.14410452472565, 16.938595340766724, 'logcosh', 'Adam', 3,
#         'relu', 128, 3],
#        [14.235895648067947, 16.23408677222984, 'logcosh', 'Nadam', 5,
#         'elu', 16, 4],
#        [11.702946186501142, 13.406005870998086, 'mean_squared_error',
#         'Adam', 5, 'elu', 32, 5],
#        [15.102110302720439, 16.04134943483807, 'logcosh', 'Adam', 10,
#         'relu', 16, 6],
#        [17.61267311061354, 17.855643389599365, 'logcosh', 'Adam', 10,
#         'relu', 512, 7],
#        [10.2986853185854, 12.249598861685035, 'mean_squared_error',
#         'Adam', 5, 'tanh', 16, 8],
#        [16.468773960305132, 17.977037238416067, 'mean_squared_error',
#         'Adam', 3, 'tanh', 128, 9]], dtype=object)

# %%
def cnn1d_val(pred,eva,test_df,sequence_length):
    sequence_cols = test_df.columns.difference(['id','cycle','RUL'])
    # We pick the last sequence for each id in the test data
    seq_array_test_last = [[test_df[test_df['id']==id][sequence_cols].values[-sequence_length:]]
                           for id in test_df['id'].unique() if test_df[test_df['id']==id]['cycle'].max()>sequence_length]

    seq_array_test_last = np.concatenate(seq_array_test_last).astype(np.float32)

    smp=seq_array_test_last.shape[0]
    n=seq_array_test_last.shape[2]

    y_mask = [test_df[test_df['id']==id]['cycle'].max()>sequence_length for id in test_df['id'].unique()]
    label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
    label_array_test_last = label_array_test_last.reshape(smp,1).astype(np.float32)
    
    scores_test = eva.evaluate(seq_array_test_last, label_array_test_last)
    
    y_pred_test = pred.predict(seq_array_test_last)
    y_true_test = label_array_test_last
    
    sf = scoring_function(y_true_test,y_pred_test)
    rmse_err = rmse(y_true_test,y_pred_test)
    m_err = merror(y_true_test,y_pred_test)
    
    print(m_err,sf,rmse_err)

# %%
def cnn2d_val(pred,eva,test_df,sequence_length):
    sequence_cols = test_df.columns.difference(['id','cycle','RUL'])
    # We pick the last sequence for each id in the test data
    seq_array_test_last = [[test_df[test_df['id']==id][sequence_cols].values[-sequence_length:]]
                           for id in test_df['id'].unique() if test_df[test_df['id']==id]['cycle'].max()>sequence_length]

    seq_array_test_last = np.concatenate(seq_array_test_last).astype(np.float32)

    smp=seq_array_test_last.shape[0]
    n=seq_array_test_last.shape[2]
    
    seq_array_test_last = seq_array_test_last.reshape(smp, sequence_length, n, 1)

    y_mask = [test_df[test_df['id']==id]['cycle'].max()>sequence_length for id in test_df['id'].unique()]
    label_array_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
    label_array_test_last = label_array_test_last.reshape(smp,1).astype(np.float32)
    
    scores_test = eva.evaluate(seq_array_test_last, label_array_test_last)
    
    y_pred_test = pred.predict(seq_array_test_last)
    y_true_test = label_array_test_last
    
    sf = scoring_function(y_true_test,y_pred_test)
    rmse_err = rmse(y_true_test,y_pred_test)
    m_err = merror(y_true_test,y_pred_test)
    
    print(m_err,sf,rmse_err)

# %%
cnn1d_val(p,e,test_df,sequence_length)
# Out:
# 11.423786992612092 [1153.0573] [18.002577]

# %%
print(run_time)
# Out:
# 300.3336408138275
